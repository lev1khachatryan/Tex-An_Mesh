# %%
import cv2
import numpy as np

# %%
img = cv2.imread('photo\he\s_heshuyu.png')

bili = 0.5
res1 = cv2.resize(img, None, fx=bili, fy=bili, interpolation=cv2.INTER_LINEAR  )#fx,fy scaling ratio
cv2.imwrite('photo\he\s_heshuyu0.5.png',res1)
# Out:
# True
