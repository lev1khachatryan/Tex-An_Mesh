# %%
import numpy as np
from time import time
from tqdm import tqdm
import pickle

# %%
with open("../../Downloads/result_levon.obj", "r") as f:
    content_pifu = f.readlines()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-df5d4e5c900b> in <module>
# ----> 1 with open("../../Downloads/result_levon.obj", "r") as f:
#       2     content_pifu = f.readlines()
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../Downloads/result_levon.obj'

# %%
def get_vertices(mesh_path, with_texture = False):
    with open(mesh_path, "r") as f:
        content = f.readlines()
    vertices = [[np.float32(v_i) for v_i in v.split('\n')[0].split(' ')[1:]] 
                for v in content if v.startswith('v ')]
    vertices = np.array(vertices)
    if with_texture:
        return vertices
    else:
        return vertices[:,:3]

# %%
def mesh_verts_align(verts_1, verts_2, eps = 1e-8):
    "this function aligns verts_2 to verts_1"
    
    # finding bounding boxes
    bbox_1_x_min, bbox_1_x_max = np.min(verts_1[:,0]), np.max(verts_1[:,0])
    bbox_1_y_min, bbox_1_y_max = np.min(verts_1[:,1]), np.max(verts_1[:,1])
    bbox_1_z_min, bbox_1_z_max = np.min(verts_1[:,2]), np.max(verts_1[:,2])
    H1 = bbox_1_z_max - bbox_1_z_min
    W1 = bbox_1_y_max - bbox_1_y_min
    D1 = bbox_1_x_max - bbox_1_x_min
    
    bbox_2_x_min, bbox_2_x_max = np.min(verts_2[:,0]), np.max(verts_2[:,0])
    bbox_2_y_min, bbox_2_y_max = np.min(verts_2[:,1]), np.max(verts_2[:,1])
    bbox_2_z_min, bbox_2_z_max = np.min(verts_2[:,2]), np.max(verts_2[:,2])
    H2 = bbox_2_z_max - bbox_2_z_min
    W2 = bbox_2_y_max - bbox_2_y_min
    D2 = bbox_2_x_max - bbox_2_x_min
    
    # get_centers
    center_1 = 0.5* np.array([(bbox_1_x_min + bbox_1_x_max), 
                              (bbox_1_y_min + bbox_1_y_max),
                              (bbox_1_z_min + bbox_1_z_max)])

    center_2 = 0.5* np.array([(bbox_2_x_min + bbox_2_x_max), 
                              (bbox_2_y_min + bbox_2_y_max),
                              (bbox_2_z_min + bbox_2_z_max)])
    
#     center_1 = np.mean(verts_1, axis=0)
#     center_2 = np.mean(verts_2, axis=0)
    
    verts_2 = verts_2 - center_2
    verts_2[:,0] = verts_2[:,0]*(D1/D2+eps) 
    verts_2[:,1] = verts_2[:,1]*(W1/W2+eps)
    verts_2[:,2] = verts_2[:,2]*(H1/H2+eps)
    
    verts_2 = verts_2 + center_1
    
    return verts_2
    
#     bbox_2_x_min, bbox_2_x_max = np.min(verts_2[:,0]), np.max(verts_2[:,0])
#     bbox_2_y_min, bbox_2_y_max = np.min(verts_2[:,1]), np.max(verts_2[:,1])
#     bbox_2_z_min, bbox_2_z_max = np.min(verts_2[:,2]), np.max(verts_2[:,2])
#     H2 = bbox_2_z_max - bbox_2_z_min
#     W2 = bbox_2_y_max - bbox_2_y_min
#     D2 = bbox_2_x_max - bbox_2_x_min
    
#     center_1 = 0.5* np.array([(bbox_1_x_min + bbox_1_x_max), 
#                               (bbox_1_y_min + bbox_1_y_max),
#                               (bbox_1_z_min + bbox_1_z_max)])

#     center_2 = 0.5* np.array([(bbox_2_x_min + bbox_2_x_max), 
#                               (bbox_2_y_min + bbox_2_y_max),
#                               (bbox_2_z_min + bbox_2_z_max)])
    
#     return center_1, center_2, (H1, W1, D1), (H2, W2, D2)

# %%
verts_smpl = get_vertices('../smpl_tf.obj')

# %%
verts_pifu = get_vertices('../../Downloads/result_levon.obj')

# %%
verts_pifu_textures = get_vertices('../../Downloads/result_levon.obj', with_texture=True)[:,3:]

# %%
verts_smpl_random = get_vertices('../../Downloads/smpl_tf.obj')

# %%
verts_smpl_aligned = mesh_verts_align(verts_pifu, verts_smpl)

# %%
verts_smpl_random_aligned = mesh_verts_align(verts_pifu, verts_smpl_random)

# %%
verts_smpl_aligned.shape
# Out:
# (6890, 3)

# %%
def change_verts_in_mesh(mesh_path, new_verts, textures=False):
    with open(mesh_path, "r") as f:
        content = f.readlines()
        lines = content#.split('\n')
        new_content = []
        for i in tqdm(range(len(lines))):
            line = lines[i]
            if not line.startswith('v '):
                new_line = line
            else: 
                verts_part = ' '.join(line.split(' ')[:4])
                if textures:
                    new_line = line.replace(verts_part, 'v '+' '.join([str(val) for val in new_verts[i]]))
                else:
                    new_line = line.replace(verts_part, 'v '+' '.join([str(val) for val in new_verts[i]])+'\n')
            new_content.append(new_line)
    return ''.join(new_content)

# %%
new_content = change_verts_in_mesh('../smpl_tf.obj', verts_smpl_aligned)
# Out:
# 100%|██████████| 20666/20666 [00:00<00:00, 437790.66it/s]

# %%
with open('../smpl_tf_aligned.obj', 'w') as file:
    file.write(new_content)

# %%
def pairwise_dist(A, B):
    # squared norms of each row in A and B
    na = np.sum(np.square(A), axis = 1)
    nb = np.sum(np.square(B), axis =  1)

    # na as a row and nb as a co"lumn vectors
    na = np.reshape(na, [-1, 1])
    nb = np.reshape(nb, [1, -1])

    # return pairwise euclidead difference matrix
    D = np.maximum(na - 2*np.matmul(A, B.T) + nb, 0.0)
    
    return D

# %%
start = time()
dists = pairwise_dist(verts_smpl_aligned, verts_pifu)
print(time()-start)
# Out:
# 2.7966830730438232

# %%
dists.shape
# Out:
# (6890, 42500)

# %%
argmins = np.argmin(dists, axis=-1)

# %%
argmins
# Out:
# array([22225, 21578, 22682, ..., 14050, 14050, 14050])

# %%
smpl_textures = verts_pifu_textures[argmins]

# %%
def add_texture_to_mesh(non_textured_mesh_path, textures):
    with open(non_textured_mesh_path, "r") as f:
        content = f.readlines()
        lines = content#.split('\n')
        new_content = []
        for i in tqdm(range(len(lines))):
            line = lines[i]
            if not line.startswith('v '):
                new_line = line
            else: 
                verts_part = ' '.join(line.split(' ')[:4])
                rep = ' '+' '.join([str(val) for val in textures[i]])+'\n'
                new_line = line.replace('\n', rep)
            new_content.append(new_line)
    return ''.join(new_content)

# %%
new_content = add_texture_to_mesh('../smpl_tf_aligned.obj', textures=smpl_textures)
# Out:
# 100%|██████████| 20666/20666 [00:00<00:00, 571956.84it/s]

# %%
with open('../smpl_tf_aligned_textured.obj', 'w') as file:
    file.write(new_content)

# %%
shifts = verts_smpl_random_aligned - verts_smpl_aligned

# %%
start = time()
dists = pairwise_dist(verts_pifu, verts_smpl_aligned)
print(time()-start)
# Out:
# 4.7361297607421875

# %%
argmins = np.argmin(dists, axis=-1)

# %%
argmins.shape
# Out:
# (42500,)

# %%
verts_pifu_new = verts_pifu + shifts[argmins]

# %%
new_content = change_verts_in_mesh('../../Downloads/result_levon.obj', verts_pifu_new, textures=True)
# Out:
# 100%|██████████| 127500/127500 [00:00<00:00, 556797.90it/s]

# %%
with open('../pifu_random.obj', 'w') as file:
    file.write(new_content)

# %%
content_pifu
# Out:
# ['v -0.4700 0.7969 0.1562 0.6455 0.4662 0.3830\n',
#  'v -0.4688 0.7969 0.1488 0.6391 0.4601 0.3765\n',
#  'v -0.4688 0.7945 0.1562 0.6393 0.4623 0.3794\n',
#  'v -0.4688 0.7920 0.1641 0.6463 0.4687 0.3844\n',
#  'v -0.4714 0.7969 0.1641 0.6529 0.4736 0.3909\n',
#  'v -0.4688 0.7907 0.1719 0.6482 0.4701 0.3850\n',
#  'v -0.4726 0.7969 0.1719 0.6555 0.4759 0.3937\n',
#  'v -0.4688 0.7904 0.1797 0.6496 0.4712 0.3859\n',
#  'v -0.4735 0.7969 0.1797 0.6546 0.4744 0.3928\n',
#  'v -0.4688 0.7900 0.1875 0.6502 0.4714 0.3857\n',
#  'v -0.4743 0.7969 0.1875 0.6536 0.4728 0.3916\n',
#  'v -0.4688 0.7908 0.1953 0.6567 0.4781 0.3924\n',
#  'v -0.4743 0.7969 0.1953 0.6526 0.4714 0.3902\n',
#  'v -0.4688 0.7922 0.2031 0.6678 0.4899 0.4044\n',
#  'v -0.4741 0.7969 0.2031 0.6514 0.4697 0.3887\n',
#  'v -0.4688 0.7934 0.2109 0.6761 0.4989 0.4136\n',
#  'v -0.4725 0.7969 0.2109 0.6596 0.4785 0.3961\n',
#  'v -0.4688 0.7943 0.2188 0.6810 0.5045 0.4195\n',
#  'v -0.4713 0.7969 0.2188 0.6639 0.4829 0.3996\n',
#  'v -0.4688 0.7954 0.2266 0.6862 0.5100 0.4252\n',
#  'v -0.4703 0.7969 0.2266 0.6664 0.4854 0.4015\n',
#  'v -0.4688 0.7969 0.2316 0.6746 0.4942 0.4089\n',
#  'v -0.4691 0.8047 0.1562 0.6137 0.4241 0.3391\n',
#  'v -0.4688 0.8047 0.1539 0.6136 0.4241 0.3390\n',
#  'v -0.4698 0.8047 0.1641 0.6117 0.4217 0.3369\n',
#  'v -0.4695 0.8047 0.1719 0.6031 0.4126 0.3285\n',
#  'v -0.4691 0.8047 0.1797 0.5903 0.3995 0.3161\n',
#  'v -0.4688 0.8047 0.1819 0.5872 0.3963 0.3130\n',
#  'v -0.4688 0.8039 0.1875 0.5847 0.3942 0.3113\n',
#  'v -0.4688 0.8027 0.1953 0.5831 0.3933 0.3109\n',
#  'v -0.4688 0.8013 0.2031 0.5830 0.3944 0.3124\n',
#  'v -0.4688 0.8001 0.2109 0.6055 0.4183 0.3355\n',
#  'v -0.4688 0.7988 0.2188 0.6397 0.4548 0.3707\n',
#  'v -0.4688 0.7978 0.2266 0.6597 0.4769 0.3920\n',
#  'v -0.4688 0.8057 0.1562 0.6110 0.4201 0.3347\n',
#  'v -0.4688 0.8064 0.1641 0.6053 0.4129 0.3273\n',
#  'v -0.4688 0.8056 0.1719 0.5979 0.4063 0.3218\n',
#  'v -0.4688 0.8050 0.1797 0.5881 0.3970 0.3136\n',
#  'v -0.4619 0.7891 0.1406 0.5952 0.4211 0.3353\n',
#  'v -0.4609 0.7891 0.1371 0.5947 0.4216 0.3357\n',
#  'v -0.4609 0.7882 0.1406 0.5919 0.4184 0.3322\n',
#  'v -0.4609 0.7868 0.1484 0.5965 0.4217 0.3343\n',
#  'v -0.4637 0.7891 0.1484 0.5982 0.4218 0.3360\n',
#  'v -0.4609 0.7860 0.1562 0.6003 0.4246 0.3363\n',
#  'v -0.4651 0.7891 0.1562 0.6103 0.4322 0.3460\n',
#  'v -0.4609 0.7858 0.1641 0.6020 0.4259 0.3372\n',
#  'v -0.4663 0.7891 0.1641 0.6295 0.4506 0.3639\n',
#  'v -0.4609 0.7860 0.1719 0.6061 0.4296 0.3405\n',
#  'v -0.4669 0.7891 0.1719 0.6390 0.4595 0.3724\n',
#  'v -0.4609 0.7863 0.1797 0.6120 0.4353 0.3458\n',
#  'v -0.4670 0.7891 0.1797 0.6412 0.4616 0.3743\n',
#  'v -0.4609 0.7873 0.1875 0.6243 0.4474 0.3575\n',
#  'v -0.4668 0.7891 0.1875 0.6429 0.4631 0.3754\n',
#  'v -0.4609 0.7883 0.1953 0.6379 0.4607 0.3702\n',
#  'v -0.4644 0.7891 0.1953 0.6423 0.4622 0.3724\n',
#  'v -0.4609 0.7891 0.2006 0.6477 0.4708 0.3799\n',
#  'v -0.4637 0.7969 0.1328 0.6328 0.4561 0.3705\n',
#  'v -0.4609 0.7969 0.1269 0.6396 0.4635 0.3751\n',
#  'v -0.4609 0.7911 0.1328 0.6046 0.4321 0.3464\n',
#  'v -0.4668 0.7969 0.1406 0.6346 0.4568 0.3728\n',
#  'v -0.4687 0.7969 0.1484 0.6389 0.4599 0.3763\n',
#  'v -0.4609 0.7896 0.2031 0.6537 0.4771 0.3863\n',
#  'v -0.4609 0.7921 0.2109 0.6749 0.4999 0.4094\n',
#  'v -0.4609 0.7960 0.2188 0.7006 0.5259 0.4353\n',
#  'v -0.4656 0.7969 0.2266 0.6898 0.5116 0.4242\n',
#  'v -0.4609 0.7969 0.2208 0.7013 0.5237 0.4321\n',
#  'v -0.4626 0.8047 0.1328 0.6044 0.4159 0.3281\n',
#  'v -0.4609 0.8047 0.1289 0.6056 0.4178 0.3275\n',
#  'v -0.4652 0.8047 0.1406 0.6055 0.4161 0.3310\n',
#  'v -0.4675 0.8047 0.1484 0.6119 0.4225 0.3373\n',
#  'v -0.4669 0.8047 0.1875 0.5768 0.3854 0.3025\n',
#  'v -0.4635 0.8047 0.1953 0.5667 0.3748 0.2911\n',
#  'v -0.4609 0.8047 0.1983 0.5652 0.3733 0.2867\n',
#  'v -0.4609 0.8033 0.2031 0.5638 0.3734 0.2872\n',
#  'v -0.4609 0.8005 0.2109 0.5997 0.4128 0.3251\n',
#  'v -0.4609 0.7974 0.2188 0.6950 0.5164 0.4247\n',
#  'v -0.4609 0.8108 0.1328 0.5832 0.3878 0.2944\n',
#  'v -0.4623 0.8125 0.1406 0.5831 0.3904 0.2990\n',
#  'v -0.4609 0.8125 0.1349 0.5851 0.3926 0.2989\n',
#  'v -0.4630 0.8125 0.1484 0.5797 0.3868 0.2969\n',
#  'v -0.4628 0.8125 0.1562 0.5758 0.3827 0.2929\n',
#  'v -0.4609 0.8125 0.1632 0.5692 0.3763 0.2845\n',
#  'v -0.4609 0.8124 0.1641 0.5678 0.3747 0.2831\n',
#  'v -0.4609 0.8103 0.1719 0.5565 0.3620 0.2725\n',
#  'v -0.4609 0.8087 0.1797 0.5572 0.3634 0.2751\n',
#  'v -0.4609 0.8069 0.1875 0.5603 0.3673 0.2801\n',
#  'v -0.4609 0.8055 0.1953 0.5657 0.3732 0.2863\n',
#  'v -0.4609 0.8143 0.1406 0.5866 0.3978 0.3041\n',
#  'v -0.4609 0.8144 0.1484 0.5834 0.3948 0.3015\n',
#  'v -0.4609 0.8137 0.1562 0.5776 0.3871 0.2944\n',
#  'v -0.4545 0.7891 0.1250 0.5980 0.4309 0.3436\n',
#  'v -0.4531 0.7891 0.1223 0.6005 0.4344 0.3468\n',
#  'v -0.4531 0.7883 0.1250 0.5949 0.4291 0.3418\n',
#  'v -0.4531 0.7868 0.1328 0.5884 0.4230 0.3362\n',
#  'v -0.4588 0.7891 0.1328 0.5926 0.4218 0.3357\n',
#  'v -0.4531 0.7859 0.1406 0.5819 0.4160 0.3295\n',
#  'v -0.4531 0.7857 0.1484 0.5842 0.4177 0.3307\n',
#  'v -0.4531 0.7858 0.1562 0.5880 0.4210 0.3336\n',
#  'v -0.4531 0.7865 0.1641 0.5972 0.4300 0.3416\n',
#  'v -0.4531 0.7874 0.1719 0.6071 0.4397 0.3506\n',
#  'v -0.4531 0.7888 0.1797 0.6306 0.4625 0.3721\n',
#  'v -0.4569 0.7891 0.1875 0.6424 0.4701 0.3794\n',
#  'v -0.4531 0.7891 0.1809 0.6339 0.4657 0.3750\n',
#  'v -0.4594 0.7891 0.1953 0.6465 0.4714 0.3806\n',
#  'v -0.4557 0.7969 0.1172 0.6571 0.4802 0.3860\n',
#  'v -0.4531 0.7969 0.1132 0.6590 0.4860 0.3913\n',
#  'v -0.4531 0.7923 0.1172 0.6303 0.4613 0.3706\n',
#  'v -0.4599 0.7969 0.1250 0.6445 0.4676 0.3777\n',
#  'v -0.4531 0.7908 0.1875 0.6611 0.4895 0.3963\n',
#  'v -0.4531 0.7928 0.1953 0.6778 0.5042 0.4098\n',
#  'v -0.4531 0.7959 0.2031 0.7121 0.5360 0.4381\n',
#  'v -0.4561 0.7969 0.2109 0.7111 0.5322 0.4353\n',
#  'v -0.4531 0.7969 0.2054 0.7133 0.5339 0.4343\n',
#  'v -0.4602 0.7969 0.2188 0.7025 0.5248 0.4324\n',
#  'v -0.4548 0.8047 0.1172 0.6035 0.4186 0.3201\n',
#  'v -0.4531 0.8047 0.1144 0.5994 0.4191 0.3193\n',
#  'v -0.4590 0.8047 0.1250 0.6065 0.4195 0.3262\n',
#  'v -0.4552 0.8047 0.1875 0.5505 0.3620 0.2701\n',
#  'v -0.4531 0.8040 0.1875 0.5483 0.3611 0.2676\n',
#  'v -0.4531 0.8047 0.1859 0.5461 0.3586 0.2648\n',
#  'v -0.4595 0.8047 0.1953 0.5618 0.3709 0.2830\n',
#  'v -0.4531 0.8013 0.1953 0.5790 0.3934 0.2993\n',
#  'v -0.4531 0.7979 0.2031 0.6973 0.5153 0.4147\n',
#  'v -0.4536 0.8125 0.1172 0.5862 0.3955 0.2905\n',
#  'v -0.4531 0.8125 0.1165 0.5862 0.3955 0.2899\n',
#  'v -0.4576 0.8125 0.1250 0.5859 0.3941 0.2951\n',
#  'v -0.4603 0.8125 0.1328 0.5858 0.3932 0.2984\n',
#  'v -0.4603 0.8125 0.1641 0.5674 0.3747 0.2822\n',
#  'v -0.4531 0.8125 0.1681 0.5531 0.3627 0.2623\n',
#  'v -0.4531 0.8110 0.1719 0.5439 0.3522 0.2524\n',
#  'v -0.4531 0.8079 0.1797 0.5435 0.3535 0.2574\n',
#  'v -0.4531 0.8137 0.1172 0.5901 0.4008 0.2954\n',
#  'v -0.4539 0.8203 0.1250 0.6122 0.4319 0.3297\n',
#  'v -0.4531 0.8203 0.1227 0.6130 0.4323 0.3292\n',
#  'v -0.4553 0.8203 0.1328 0.6090 0.4293 0.3288\n',
#  'v -0.4557 0.8203 0.1406 0.6052 0.4254 0.3256\n',
#  'v -0.4547 0.8203 0.1484 0.6022 0.4213 0.3209\n',
#  'v -0.4531 0.8203 0.1554 0.5993 0.4169 0.3153\n',
#  'v -0.4531 0.8200 0.1562 0.5975 0.4147 0.3130\n',
#  'v -0.4531 0.8152 0.1641 0.5703 0.3823 0.2809\n',
#  'v -0.4531 0.8215 0.1250 0.6177 0.4385 0.3357\n',
#  'v -0.4531 0.8235 0.1328 0.6277 0.4476 0.3444\n',
#  'v -0.4531 0.8236 0.1406 0.6256 0.4465 0.3438\n',
#  'v -0.4531 0.8222 0.1484 0.6107 0.4312 0.3296\n',
#  'v -0.4478 0.7891 0.1094 0.5966 0.4340 0.3450\n',
#  'v -0.4453 0.7891 0.1052 0.5962 0.4377 0.3476\n',
#  'v -0.4453 0.7869 0.1094 0.5857 0.4263 0.3375\n',
#  'v -0.4453 0.7849 0.1172 0.5646 0.4072 0.3201\n',
#  'v -0.4512 0.7891 0.1172 0.5983 0.4341 0.3467\n',
#  'v -0.4453 0.7836 0.1250 0.5545 0.3973 0.3105\n',
#  'v -0.4453 0.7828 0.1328 0.5486 0.3899 0.3026\n',
#  'v -0.4453 0.7830 0.1406 0.5524 0.3930 0.3052\n',
#  'v -0.4453 0.7836 0.1484 0.5581 0.3987 0.3105\n',
#  'v -0.4453 0.7846 0.1562 0.5666 0.4074 0.3188\n',
#  'v -0.4453 0.7859 0.1641 0.5796 0.4186 0.3289\n',
#  'v -0.4453 0.7878 0.1719 0.6214 0.4560 0.3625\n',
#  'v -0.4511 0.7891 0.1797 0.6274 0.4602 0.3694\n',
#  'v -0.4453 0.7891 0.1770 0.6489 0.4812 0.3856\n',
#  'v -0.4456 0.7969 0.1016 0.6625 0.5088 0.4146\n',
#  'v -0.4453 0.7969 0.1011 0.6634 0.5102 0.4159\n',
#  'v -0.4453 0.7962 0.1016 0.6618 0.5096 0.4164\n',
#  'v -0.4505 0.7969 0.1094 0.6559 0.4913 0.3968\n',
#  'v -0.4453 0.7902 0.1797 0.6734 0.5026 0.4043\n',
#  'v -0.4453 0.7940 0.1875 0.7193 0.5449 0.4430\n',
#  'v -0.4470 0.7969 0.1953 0.7277 0.5499 0.4449\n',
#  'v -0.4453 0.7969 0.1928 0.7327 0.5557 0.4501\n',
#  'v -0.4516 0.7969 0.2031 0.7142 0.5349 0.4338\n',
#  'v -0.4453 0.7979 0.1016 0.6525 0.4970 0.4016\n',
#  'v -0.4498 0.8047 0.1094 0.5930 0.4190 0.3165\n',
#  'v -0.4453 0.8047 0.1036 0.5930 0.4273 0.3272\n',
#  'v -0.4453 0.8002 0.1875 0.6501 0.4697 0.3681\n',
#  'v -0.4453 0.8047 0.1800 0.5500 0.3650 0.2688\n',
#  'v -0.4490 0.8125 0.1094 0.5865 0.3967 0.2850\n',
#  'v -0.4453 0.8125 0.1045 0.6002 0.4159 0.3074\n',
#  'v -0.4453 0.8107 0.1719 0.5497 0.3592 0.2580\n',
#  'v -0.4453 0.8125 0.1695 0.5613 0.3711 0.2687\n',
#  'v -0.4453 0.8050 0.1797 0.5482 0.3630 0.2667\n',
#  'v -0.4467 0.8203 0.1094 0.6261 0.4453 0.3386\n',
#  'v -0.4453 0.8203 0.1076 0.6312 0.4532 0.3477\n',
#  'v -0.4508 0.8203 0.1172 0.6144 0.4323 0.3268\n',
#  'v -0.4529 0.8203 0.1562 0.5987 0.4161 0.3144\n',
#  'v -0.4492 0.8203 0.1641 0.5920 0.4065 0.3022\n',
#  'v -0.4453 0.8203 0.1686 0.6118 0.4265 0.3228\n',
#  'v -0.4453 0.8230 0.1094 0.6490 0.4686 0.3621\n',
#  'v -0.4463 0.8281 0.1172 0.6672 0.4829 0.3761\n',
#  'v -0.4453 0.8281 0.1148 0.6727 0.4881 0.3810\n',
#  'v -0.4486 0.8281 0.1250 0.6549 0.4706 0.3647\n',
#  'v -0.4500 0.8281 0.1328 0.6500 0.4673 0.3624\n',
#  'v -0.4502 0.8281 0.1406 0.6474 0.4655 0.3613\n',
#  'v -0.4495 0.8281 0.1484 0.6462 0.4645 0.3604\n',
#  'v -0.4479 0.8281 0.1562 0.6516 0.4694 0.3649\n',
#  'v -0.4453 0.8281 0.1640 0.6640 0.4813 0.3762\n',
#  'v -0.4453 0.8281 0.1641 0.6638 0.4811 0.3760\n',
#  'v -0.4453 0.8287 0.1172 0.6730 0.4890 0.3824\n',
#  'v -0.4453 0.8301 0.1250 0.6752 0.4916 0.3858\n',
#  'v -0.4453 0.8310 0.1328 0.6772 0.4935 0.3880\n',
#  'v -0.4453 0.8314 0.1406 0.6779 0.4941 0.3887\n',
#  'v -0.4453 0.8312 0.1484 0.6761 0.4924 0.3872\n',
#  'v -0.4453 0.8302 0.1562 0.6722 0.4890 0.3838\n',
#  'v -0.4390 0.7812 0.1016 0.5577 0.4043 0.3111\n',
#  'v -0.4375 0.7812 0.0975 0.5629 0.4119 0.3170\n',
#  'v -0.4375 0.7806 0.1016 0.5621 0.4083 0.3124\n',
#  'v -0.4375 0.7798 0.1094 0.5569 0.4025 0.3062\n',
#  'v -0.4410 0.7812 0.1094 0.5499 0.3959 0.3052\n',
#  'v -0.4375 0.7793 0.1172 0.5575 0.4014 0.3040\n',
#  'v -0.4424 0.7812 0.1172 0.5457 0.3903 0.3007\n',
#  'v -0.4375 0.7790 0.1250 0.5586 0.4011 0.3027\n',
#  'v -0.4433 0.7812 0.1250 0.5439 0.3869 0.2976\n',
#  'v -0.4375 0.7790 0.1328 0.5595 0.4007 0.3017\n',
#  'v -0.4438 0.7812 0.1328 0.5431 0.3843 0.2950\n',
#  'v -0.4375 0.7793 0.1406 0.5640 0.4039 0.3044\n',
#  'v -0.4432 0.7812 0.1406 0.5453 0.3858 0.2955\n',
#  'v -0.4375 0.7800 0.1484 0.5868 0.4221 0.3202\n',
#  'v -0.4415 0.7812 0.1484 0.5522 0.3934 0.3007\n',
#  'v -0.4375 0.7811 0.1562 0.6016 0.4357 0.3333\n',
#  'v -0.4379 0.7812 0.1562 0.6001 0.4342 0.3325\n',
#  'v -0.4375 0.7812 0.1569 0.6028 0.4369 0.3345\n',
#  'v -0.4382 0.7891 0.0859 0.6092 0.4538 0.3579\n',
#  'v -0.4375 0.7891 0.0841 0.6120 0.4565 0.3596\n',
#  'v -0.4375 0.7880 0.0859 0.6006 0.4482 0.3527\n',
#  'v -0.4375 0.7836 0.0938 0.5731 0.4261 0.3324\n',
#  'v -0.4409 0.7891 0.0938 0.5996 0.4461 0.3534\n',
#  'v -0.4437 0.7891 0.1016 0.5950 0.4395 0.3489\n',
#  'v -0.4375 0.7839 0.1641 0.6219 0.4562 0.3547\n',
#  'v -0.4375 0.7872 0.1719 0.6511 0.4853 0.3842\n',
#  'v -0.4375 0.7891 0.1764 0.6857 0.5150 0.4111\n',
#  'v -0.4395 0.7969 0.0859 0.6395 0.4954 0.4029\n',
#  'v -0.4375 0.7969 0.0800 0.6363 0.4950 0.4027\n',
#  'v -0.4422 0.7969 0.0938 0.6529 0.5036 0.4099\n',
#  'v -0.4375 0.7916 0.1797 0.7141 0.5415 0.4364\n',
#  'v -0.4375 0.7968 0.1875 0.7402 0.5674 0.4623\n',
#  'v -0.4375 0.7969 0.1877 0.7399 0.5669 0.4618\n',
#  'v -0.4375 0.8031 0.0859 0.6102 0.4569 0.3641\n',
#  'v -0.4399 0.8047 0.0938 0.6073 0.4480 0.3517\n',
#  'v -0.4375 0.8047 0.0874 0.6096 0.4549 0.3618\n',
#  'v -0.4439 0.8047 0.1016 0.5969 0.4322 0.3329\n',
#  'v -0.4437 0.8047 0.1797 0.5597 0.3746 0.2785\n',
#  'v -0.4375 0.8035 0.1797 0.6357 0.4545 0.3576\n',
#  'v -0.4375 0.8047 0.1786 0.6150 0.4314 0.3355\n',
#  'v -0.4375 0.7970 0.1875 0.7392 0.5660 0.4609\n',
#  'v -0.4379 0.8125 0.0938 0.6121 0.4499 0.3547\n',
#  'v -0.4375 0.8125 0.0931 0.6144 0.4525 0.3578\n',
#  'v -0.4430 0.8125 0.1016 0.5982 0.4228 0.3191\n',
#  'v -0.4405 0.8125 0.1719 0.5804 0.3898 0.2918\n',
#  'v -0.4375 0.8125 0.1732 0.6023 0.4121 0.3160\n',
#  'v -0.4375 0.8132 0.0938 0.6200 0.4590 0.3643\n',
#  'v -0.4399 0.8203 0.1016 0.6526 0.4845 0.3838\n',
#  'v -0.4375 0.8203 0.0992 0.6624 0.4988 0.4006\n',
#  'v -0.4415 0.8203 0.1719 0.6395 0.4560 0.3534\n',
#  'v -0.4375 0.8203 0.1748 0.6631 0.4811 0.3806\n',
#  'v -0.4375 0.8227 0.1016 0.6795 0.5092 0.4078\n',
#  'v -0.4408 0.8281 0.1094 0.6940 0.5097 0.4021\n',
#  'v -0.4375 0.8281 0.1071 0.7085 0.5245 0.4169\n',
#  'v -0.4453 0.8281 0.1641 0.6641 0.4814 0.3763\n',
#  'v -0.4419 0.8281 0.1719 0.6793 0.4957 0.3897\n',
#  'v -0.4375 0.8281 0.1776 0.7051 0.5226 0.4158\n',
#  'v -0.4375 0.8288 0.1094 0.7089 0.5253 0.4177\n',
#  'v -0.4375 0.8303 0.1172 0.7105 0.5270 0.4189\n',
#  'v -0.4375 0.8313 0.1250 0.7116 0.5283 0.4197\n',
#  'v -0.4375 0.8319 0.1328 0.7121 0.5292 0.4204\n',
#  'v -0.4375 0.8322 0.1406 0.7127 0.5299 0.4209\n',
#  'v -0.4375 0.8324 0.1484 0.7128 0.5301 0.4209\n',
#  'v -0.4375 0.8322 0.1562 0.7131 0.5305 0.4213\n',
#  'v -0.4375 0.8313 0.1641 0.7129 0.5302 0.4209\n',
#  'v -0.4375 0.8298 0.1719 0.7089 0.5269 0.4189\n',
#  'v -0.4298 0.7734 0.1094 0.6299 0.4547 0.3372\n',
#  'v -0.4297 0.7734 0.1082 0.6308 0.4555 0.3378\n',
#  'v -0.4297 0.7734 0.1094 0.6305 0.4551 0.3374\n',
#  'v -0.4297 0.7733 0.1172 0.6284 0.4527 0.3352\n',
#  'v -0.4300 0.7734 0.1172 0.6268 0.4518 0.3347\n',
#  'v -0.4297 0.7734 0.1221 0.6268 0.4514 0.3341\n',
#  'v -0.4319 0.7812 0.0781 0.5764 0.4371 0.3369\n',
#  'v -0.4297 0.7812 0.0731 0.5975 0.4509 0.3458\n',
#  'v -0.4297 0.7793 0.0781 0.5844 0.4400 0.3349\n',
#  'v -0.4297 0.7775 0.0859 0.6132 0.4474 0.3349\n',
#  'v -0.4338 0.7812 0.0859 0.5714 0.4294 0.3311\n',
#  'v -0.4297 0.7757 0.0938 0.6249 0.4544 0.3391\n',
#  'v -0.4362 0.7812 0.0938 0.5656 0.4177 0.3217\n',
#  'v -0.4297 0.7743 0.1016 0.6318 0.4577 0.3405\n',
#  'v -0.4297 0.7736 0.1250 0.6259 0.4507 0.3336\n',
#  'v -0.4297 0.7749 0.1328 0.6252 0.4510 0.3348\n',
#  'v -0.4297 0.7759 0.1406 0.6274 0.4538 0.3379\n',
#  'v -0.4297 0.7775 0.1484 0.6333 0.4598 0.3443\n',
#  'v -0.4297 0.7794 0.1562 0.6367 0.4633 0.3480\n',
#  'v -0.4297 0.7812 0.1624 0.6464 0.4744 0.3607\n',
#  'v -0.4342 0.7891 0.0781 0.6221 0.4686 0.3689\n',
#  'v -0.4297 0.7891 0.0712 0.6427 0.4906 0.3884\n',
#  'v -0.4297 0.7824 0.1641 0.6514 0.4806 0.3682\n',
#  'v -0.4297 0.7874 0.1719 0.6889 0.5190 0.4093\n',
#  'v -0.4297 0.7891 0.1748 0.7077 0.5373 0.4277\n',
#  'v -0.4304 0.7969 0.0703 0.6519 0.5175 0.4268\n',
#  'v -0.4297 0.7969 0.0694 0.6580 0.5237 0.4331\n',
#  'v -0.4297 0.7930 0.0703 0.6544 0.5154 0.4194\n',
#  'v -0.4364 0.7969 0.0781 0.6334 0.4938 0.4018\n',
#  'v -0.4297 0.7933 0.1797 0.7402 0.5729 0.4660\n',
#  'v -0.4371 0.7969 0.1875 0.7402 0.5674 0.4623\n',
#  'v -0.4297 0.7969 0.1843 0.7508 0.5847 0.4809\n',
#  'v -0.4297 0.7981 0.0703 0.6532 0.5179 0.4282\n',
#  'v -0.4320 0.8047 0.0781 0.6417 0.4924 0.4040\n',
#  'v -0.4297 0.8047 0.0756 0.6622 0.5117 0.4241\n',
#  'v -0.4366 0.8047 0.0859 0.6115 0.4579 0.3658\n',
#  'v -0.4297 0.8027 0.1797 0.7209 0.5489 0.4516\n',
#  'v -0.4297 0.8047 0.1784 0.7077 0.5346 0.4401\n',
#  'v -0.4297 0.8075 0.0781 0.6699 0.5172 0.4312\n',
#  'v -0.4306 0.8125 0.0859 0.6590 0.5010 0.4153\n',
#  'v -0.4297 0.8125 0.0847 0.6687 0.5104 0.4254\n',
#  'v -0.4297 0.8125 0.1748 0.6750 0.4964 0.4077\n',
#  'v -0.4297 0.8131 0.0859 0.6681 0.5114 0.4267\n',
#  'v -0.4297 0.8182 0.0938 0.6839 0.5210 0.4308\n',
#  'v -0.4297 0.8203 0.0960 0.6959 0.5260 0.4320\n',
#  'v -0.4297 0.8203 0.1764 0.7159 0.5358 0.4384\n',
#  'v -0.4297 0.8239 0.1016 0.7164 0.5414 0.4435\n',
#  'v -0.4297 0.8281 0.1086 0.7294 0.5497 0.4465\n',
#  'v -0.4297 0.8281 0.1774 0.7327 0.5532 0.4491\n',
#  'v -0.4297 0.8282 0.1094 0.7296 0.5499 0.4465\n',
#  'v -0.4297 0.8292 0.1172 0.7314 0.5512 0.4467\n',
#  'v -0.4297 0.8297 0.1250 0.7331 0.5524 0.4470\n',
#  'v -0.4297 0.8300 0.1328 0.7328 0.5521 0.4465\n',
#  'v -0.4297 0.8303 0.1406 0.7321 0.5516 0.4458\n',
#  'v -0.4297 0.8304 0.1484 0.7313 0.5509 0.4449\n',
#  'v -0.4297 0.8303 0.1562 0.7309 0.5505 0.4446\n',
#  'v -0.4297 0.8299 0.1641 0.7311 0.5510 0.4452\n',
#  'v -0.4297 0.8291 0.1719 0.7316 0.5519 0.4468\n',
#  'v -0.4221 0.7656 0.0938 0.6626 0.4651 0.3423\n',
#  'v -0.4219 0.7656 0.0885 0.6638 0.4658 0.3430\n',
#  'v -0.4219 0.7654 0.0938 0.6635 0.4653 0.3425\n',
#  'v -0.4219 0.7652 0.1016 0.6629 0.4644 0.3416\n',
#  'v -0.4223 0.7656 0.1016 0.6610 0.4641 0.3413\n',
#  'v -0.4219 0.7652 0.1094 0.6626 0.4638 0.3409\n',
#  'v -0.4224 0.7656 0.1094 0.6602 0.4630 0.3402\n',
#  'v -0.4219 0.7656 0.1149 0.6633 0.4647 0.3416\n',
#  'v -0.4228 0.7734 0.0703 0.6663 0.4768 0.3520\n',
#  'v -0.4219 0.7734 0.0681 0.6713 0.4795 0.3536\n',
#  'v -0.4219 0.7721 0.0703 0.6696 0.4767 0.3514\n',
#  'v -0.4219 0.7686 0.0781 0.6672 0.4713 0.3474\n',
#  'v -0.4248 0.7734 0.0781 0.6555 0.4718 0.3494\n',
#  'v -0.4219 0.7660 0.0859 0.6642 0.4666 0.3437\n',
#  'v -0.4266 0.7734 0.0859 0.6486 0.4683 0.3476\n',
#  'v -0.4280 0.7734 0.0938 0.6422 0.4643 0.3449\n',
#  'v -0.4290 0.7734 0.1016 0.6362 0.4597 0.3412\n',
#  'v -0.4219 0.7660 0.1172 0.6637 0.4655 0.3422\n',
#  'v -0.4219 0.7677 0.1250 0.6648 0.4684 0.3450\n',
#  'v -0.4295 0.7734 0.1250 0.6273 0.4514 0.3340\n',
#  'v -0.4219 0.7695 0.1328 0.6657 0.4708 0.3472\n',
#  'v -0.4275 0.7734 0.1328 0.6387 0.4586 0.3395\n',
#  'v -0.4219 0.7720 0.1406 0.6671 0.4742 0.3499\n',
#  'v -0.4244 0.7734 0.1406 0.6567 0.4701 0.3478\n',
#  'v -0.4219 0.7734 0.1449 0.6676 0.4758 0.3512\n',
#  'v -0.4271 0.7812 0.0703 0.6227 0.4669 0.3560\n',
#  'v -0.4219 0.7812 0.0651 0.6904 0.5112 0.3855\n',
#  'v -0.4219 0.7751 0.1484 0.6673 0.4770 0.3518\n',
#  'v -0.4219 0.7788 0.1562 0.6678 0.4806 0.3547\n',
#  'v -0.4219 0.7812 0.1615 0.6736 0.4913 0.3682\n',
#  'v -0.4285 0.7891 0.0703 0.6484 0.4967 0.3941\n',
#  'v -0.4219 0.7891 0.0664 0.6950 0.5385 0.4304\n',
#  'v -0.4219 0.7832 0.1641 0.6857 0.5056 0.3845\n',
#  'v -0.4219 0.7888 0.1719 0.7310 0.5592 0.4443\n',
#  'v -0.4219 0.7891 0.1723 0.7332 0.5620 0.4474\n',
#  'v -0.4219 0.7969 0.0680 0.7066 0.5721 0.4818\n',
#  'v -0.4219 0.7966 0.1797 0.7675 0.6133 0.5122\n',
#  'v -0.4219 0.7969 0.1799 0.7675 0.6131 0.5125\n',
#  'v -0.4219 0.7995 0.0703 0.7098 0.5686 0.4804\n',
#  'v -0.4219 0.8047 0.0756 0.7138 0.5608 0.4772\n',
#  'v -0.4219 0.7978 0.1797 0.7667 0.6117 0.5125\n',
#  'v -0.4219 0.8047 0.1774 0.7575 0.5978 0.5096\n',
#  'v -0.4219 0.8070 0.0781 0.7170 0.5607 0.4798\n',
#  'v -0.4243 0.8125 0.0859 0.6985 0.5390 0.4596\n',
#  'v -0.4219 0.8122 0.0859 0.7064 0.5449 0.4677\n',
#  'v -0.4219 0.8125 0.0864 0.7049 0.5437 0.4665\n',
#  'v -0.4219 0.8125 0.1750 0.7487 0.5848 0.5050\n',
#  'v -0.4219 0.8166 0.0938 0.7122 0.5430 0.4592\n',
#  'v -0.4219 0.8203 0.0992 0.7305 0.5627 0.4754\n',
#  'v -0.4219 0.8203 0.1746 0.7442 0.5772 0.4891\n',
#  'v -0.4219 0.8211 0.1016 0.7312 0.5630 0.4748\n',
#  'v -0.4293 0.8281 0.1094 0.7299 0.5505 0.4476\n',
#  'v -0.4219 0.8235 0.1094 0.7325 0.5639 0.4734\n',
#  'v -0.4264 0.8281 0.1172 0.7338 0.5559 0.4557\n',
#  'v -0.4219 0.8251 0.1172 0.7346 0.5649 0.4723\n',
#  'v -0.4250 0.8281 0.1250 0.7356 0.5585 0.4594\n',
#  'v -0.4219 0.8260 0.1250 0.7365 0.5660 0.4720\n',
#  'v -0.4241 0.8281 0.1328 0.7369 0.5604 0.4619\n',
#  'v -0.4219 0.8266 0.1328 0.7380 0.5670 0.4720\n',
#  'v -0.4234 0.8281 0.1406 0.7378 0.5621 0.4642\n',
#  'v -0.4219 0.8270 0.1406 0.7390 0.5673 0.4717\n',
#  'v -0.4233 0.8281 0.1484 0.7374 0.5621 0.4643\n',
#  'v -0.4219 0.8271 0.1484 0.7398 0.5679 0.4721\n',
#  'v -0.4235 0.8281 0.1562 0.7370 0.5620 0.4641\n',
#  'v -0.4219 0.8270 0.1562 0.7400 0.5688 0.4731\n',
#  'v -0.4249 0.8281 0.1641 0.7369 0.5605 0.4610\n',
#  'v -0.4219 0.8254 0.1641 0.7403 0.5702 0.4761\n',
#  'v -0.4272 0.8281 0.1719 0.7341 0.5564 0.4546\n',
#  'v -0.4219 0.8220 0.1719 0.7433 0.5754 0.4854\n',
#  'v -0.4177 0.7656 0.0703 0.6832 0.4735 0.3483\n',
#  'v -0.4141 0.7656 0.0629 0.6871 0.4813 0.3555\n',
#  'v -0.4141 0.7630 0.0703 0.6828 0.4773 0.3540\n',
#  'v -0.4141 0.7612 0.0781 0.6813 0.4784 0.3572\n',
#  'v -0.4202 0.7656 0.0781 0.6725 0.4690 0.3453\n',
#  'v -0.4141 0.7599 0.0859 0.6841 0.4800 0.3587\n',
#  'v -0.4217 0.7656 0.0859 0.6648 0.4663 0.3435\n',
#  'v -0.4141 0.7596 0.0938 0.6843 0.4802 0.3590\n',
#  'v -0.4141 0.7597 0.1016 0.6846 0.4810 0.3597\n',
#  'v -0.4141 0.7602 0.1094 0.6856 0.4821 0.3602\n',
#  'v -0.4141 0.7612 0.1172 0.6854 0.4811 0.3582\n',
#  'v -0.4215 0.7656 0.1172 0.6661 0.4665 0.3431\n',
#  'v -0.4141 0.7629 0.1250 0.6858 0.4793 0.3551\n',
#  'v -0.4191 0.7656 0.1250 0.6777 0.4719 0.3474\n',
#  'v -0.4141 0.7655 0.1328 0.6847 0.4796 0.3540\n',
#  'v -0.4143 0.7656 0.1328 0.6848 0.4795 0.3539\n',
#  'v -0.4141 0.7656 0.1331 0.6848 0.4798 0.3542\n',
#  'v -0.4141 0.7734 0.0625 0.7019 0.5035 0.3706\n',
#  'v -0.4141 0.7697 0.1406 0.6862 0.4856 0.3578\n',
#  'v -0.4141 0.7734 0.1473 0.6867 0.4903 0.3606\n',
#  'v -0.4159 0.7812 0.0625 0.7193 0.5285 0.3932\n',
#  'v -0.4141 0.7812 0.0618 0.7220 0.5337 0.3981\n',
#  'v -0.4141 0.7738 0.0625 0.7026 0.5047 0.3715\n',
#  'v -0.4141 0.7743 0.1484 0.6866 0.4912 0.3611\n',
#  'v -0.4141 0.7792 0.1562 0.6869 0.4971 0.3640\n',
#  'v -0.4141 0.7812 0.1594 0.6960 0.5089 0.3780\n',
#  'v -0.4141 0.7830 0.0625 0.7253 0.5407 0.4090\n',
#  'v -0.4141 0.7891 0.0651 0.7364 0.5667 0.4484\n',
#  'v -0.4141 0.7855 0.1641 0.7212 0.5424 0.4176\n',
#  'v -0.4211 0.7891 0.1719 0.7358 0.5646 0.4495\n',
#  'v -0.4141 0.7891 0.1680 0.7535 0.5855 0.4658\n',
#  'v -0.4141 0.7969 0.0686 0.7452 0.5980 0.4991\n',
#  'v -0.4141 0.7939 0.1719 0.7804 0.6316 0.5230\n',
#  'v -0.4214 0.7969 0.1797 0.7683 0.6146 0.5141\n',
#  'v -0.4141 0.7969 0.1746 0.7824 0.6377 0.5357\n',
#  'v -0.4141 0.7987 0.0703 0.7435 0.5962 0.5005\n',
#  'v -0.4141 0.8047 0.0779 0.7298 0.5813 0.4956\n',
#  'v -0.4141 0.8047 0.1737 0.7786 0.6326 0.5453\n',
#  'v -0.4141 0.8048 0.0781 0.7292 0.5807 0.4952\n',
#  'v -0.4141 0.8092 0.0859 0.7145 0.5616 0.4826\n',
#  'v -0.4141 0.8125 0.0911 0.7162 0.5621 0.4848\n',
#  'v -0.4141 0.8125 0.1726 0.7652 0.6179 0.5417\n',
#  'v -0.4141 0.8135 0.0938 0.7215 0.5675 0.4897\n',
#  'v -0.4204 0.8203 0.1016 0.7328 0.5676 0.4825\n',
#  'v -0.4141 0.8164 0.1016 0.7357 0.5823 0.5030\n',
#  'v -0.4165 0.8203 0.1094 0.7371 0.5789 0.4979\n',
#  'v -0.4141 0.8188 0.1094 0.7356 0.5801 0.4984\n',
#  'v -0.4141 0.8203 0.1170 0.7352 0.5785 0.4951\n',
#  'v -0.4155 0.8203 0.1641 0.7468 0.5884 0.5053\n',
#  'v -0.4141 0.8187 0.1641 0.7480 0.5922 0.5094\n',
#  'v -0.4141 0.8203 0.1598 0.7430 0.5847 0.5000\n',
#  'v -0.4200 0.8203 0.1719 0.7484 0.5847 0.4994\n',
#  'v -0.4141 0.8133 0.1719 0.7632 0.6149 0.5379\n',
#  'v -0.4141 0.8203 0.1172 0.7352 0.5785 0.4950\n',
#  'v -0.4141 0.8207 0.1250 0.7364 0.5790 0.4949\n',
#  'v -0.4141 0.8209 0.1328 0.7373 0.5795 0.4949\n',
#  'v -0.4141 0.8210 0.1406 0.7385 0.5801 0.4953\n',
#  'v -0.4141 0.8211 0.1484 0.7403 0.5814 0.4962\n',
#  'v -0.4141 0.8207 0.1562 0.7429 0.5841 0.4990\n',
#  'v -0.4079 0.7578 0.0703 0.6863 0.4903 0.3675\n',
#  'v -0.4062 0.7578 0.0660 0.6850 0.4920 0.3688\n',
#  'v -0.4062 0.7569 0.0703 0.6843 0.4914 0.3686\n',
#  'v -0.4062 0.7555 0.0781 0.6828 0.4904 0.3685\n',
#  'v -0.4103 0.7578 0.0781 0.6874 0.4878 0.3659\n',
#  'v -0.4062 0.7546 0.0859 0.6806 0.4889 0.3679\n',
#  'v -0.4118 0.7578 0.0859 0.6869 0.4854 0.3643\n',
#  'v -0.4062 0.7544 0.0938 0.6795 0.4883 0.3677\n',
#  'v -0.4120 0.7578 0.0938 0.6852 0.4842 0.3634\n',
#  'v -0.4062 0.7545 0.1016 0.6809 0.4899 0.3689\n',
#  'v -0.4119 0.7578 0.1016 0.6850 0.4846 0.3639\n',
#  'v -0.4062 0.7552 0.1094 0.6834 0.4923 0.3705\n',
#  'v -0.4109 0.7578 0.1094 0.6851 0.4869 0.3656\n',
#  'v -0.4062 0.7561 0.1172 0.6857 0.4942 0.3715\n',
#  'v -0.4092 0.7578 0.1172 0.6866 0.4910 0.3687\n',
#  'v -0.4062 0.7578 0.1233 0.6849 0.4928 0.3689\n',
#  'v -0.4131 0.7656 0.0625 0.6876 0.4833 0.3573\n',
#  'v -0.4062 0.7656 0.0594 0.6932 0.5014 0.3741\n',
#  'v -0.4062 0.7620 0.0625 0.6853 0.4934 0.3691\n',
#  'v -0.4062 0.7587 0.1250 0.6834 0.4914 0.3671\n',
#  'v -0.4062 0.7632 0.1328 0.6817 0.4883 0.3626\n',
#  'v -0.4062 0.7656 0.1376 0.6836 0.4916 0.3648\n',
#  'v -0.4140 0.7734 0.0625 0.7019 0.5037 0.3708\n',
#  'v -0.4062 0.7734 0.0602 0.7102 0.5233 0.3894\n',
#  'v -0.4062 0.7682 0.1406 0.6866 0.4968 0.3689\n',
#  'v -0.4062 0.7734 0.1483 0.6909 0.5057 0.3747\n',
#  'v -0.4062 0.7812 0.0611 0.7262 0.5485 0.4126\n',
#  'v -0.4062 0.7736 0.1484 0.6910 0.5060 0.3748\n',
#  'v -0.4062 0.7796 0.1562 0.6930 0.5145 0.3803\n',
#  'v -0.4062 0.7812 0.1585 0.7026 0.5257 0.3932\n',
#  'v -0.4062 0.7840 0.0625 0.7311 0.5587 0.4277\n',
#  'v -0.4062 0.7891 0.0656 0.7399 0.5773 0.4549\n',
#  'v -0.4072 0.7891 0.1641 0.7691 0.6114 0.4881\n',
#  'v -0.4062 0.7891 0.1635 0.7705 0.6142 0.4906\n',
#  'v -0.4062 0.7960 0.0703 0.7442 0.5968 0.4874\n',
#  'v -0.4083 0.7969 0.0703 0.7449 0.5958 0.4890\n',
#  'v -0.4062 0.7969 0.0711 0.7421 0.5952 0.4868\n',
#  'v -0.4062 0.7899 0.1641 0.7745 0.6212 0.4996\n',
#  'v -0.4111 0.7969 0.1719 0.7858 0.6437 0.5390\n',
#  'v -0.4062 0.7969 0.1683 0.7902 0.6522 0.5437\n',
#  'v -0.4138 0.8047 0.0781 0.7298 0.5810 0.4946\n',
#  'v -0.4062 0.8013 0.0781 0.7238 0.5779 0.4744\n',
#  'v -0.4062 0.8047 0.0851 0.7185 0.5752 0.4764\n',
#  'v -0.4119 0.8047 0.1719 0.7772 0.6341 0.5438\n',
#  'v -0.4062 0.8047 0.1672 0.7740 0.6359 0.5372\n',
#  'v -0.4062 0.8050 0.0859 0.7191 0.5760 0.4776\n',
#  'v -0.4123 0.8125 0.0938 0.7206 0.5698 0.4895\n',
#  'v -0.4062 0.8083 0.0938 0.7251 0.5834 0.4885\n',
#  'v -0.4077 0.8125 0.1016 0.7305 0.5873 0.4985\n',
#  'v -0.4062 0.8115 0.1016 0.7289 0.5875 0.4955\n',
#  'v -0.4062 0.8125 0.1045 0.7267 0.5856 0.4944\n',
#  'v -0.4076 0.8125 0.1641 0.7392 0.5999 0.5127\n',
#  'v -0.4062 0.8101 0.1641 0.7431 0.6074 0.5167\n',
#  'v -0.4062 0.8125 0.1618 0.7306 0.5935 0.5042\n',
#  'v -0.4134 0.8125 0.1719 0.7648 0.6183 0.5407\n',
#  'v -0.4062 0.8130 0.1094 0.7253 0.5846 0.4939\n',
#  'v -0.4140 0.8203 0.1172 0.7352 0.5785 0.4950\n',
#  'v -0.4062 0.8135 0.1172 0.7238 0.5835 0.4934\n',
#  'v -0.4137 0.8203 0.1250 0.7361 0.5792 0.4952\n',
#  'v -0.4062 0.8138 0.1250 0.7230 0.5831 0.4932\n',
#  'v -0.4135 0.8203 0.1328 0.7372 0.5800 0.4955\n',
#  'v -0.4062 0.8139 0.1328 0.7229 0.5834 0.4937\n',
#  'v -0.4134 0.8203 0.1406 0.7381 0.5807 0.4959\n',
#  'v -0.4062 0.8140 0.1406 0.7225 0.5835 0.4941\n',
#  'v -0.4133 0.8203 0.1484 0.7396 0.5820 0.4969\n',
#  'v -0.4062 0.8138 0.1484 0.7232 0.5847 0.4954\n',
#  'v -0.4137 0.8203 0.1562 0.7426 0.5844 0.4993\n',
#  'v -0.4062 0.8133 0.1562 0.7263 0.5880 0.4986\n',
#  'v -0.3993 0.7500 0.0703 0.6648 0.4853 0.3600\n',
#  'v -0.3984 0.7500 0.0672 0.6665 0.4866 0.3596\n',
#  'v -0.3984 0.7494 0.0703 0.6644 0.4852 0.3584\n',
#  'v -0.3984 0.7482 0.0781 0.6595 0.4819 0.3554\n',
#  'v -0.4010 0.7500 0.0781 0.6606 0.4823 0.3601\n',
#  'v -0.3984 0.7477 0.0859 0.6601 0.4819 0.3556\n',
#  'v -0.4015 0.7500 0.0859 0.6610 0.4826 0.3610\n',
#  'v -0.3984 0.7477 0.0938 0.6629 0.4839 0.3569\n',
#  'v -0.4015 0.7500 0.0938 0.6638 0.4846 0.3623\n',
#  'v -0.3984 0.7478 0.1016 0.6654 0.4858 0.3578\n',
#  'v -0.4013 0.7500 0.1016 0.6669 0.4869 0.3635\n',
#  'v -0.3984 0.7485 0.1094 0.6664 0.4861 0.3569\n',
#  'v -0.4003 0.7500 0.1094 0.6681 0.4874 0.3615\n',
#  'v -0.3984 0.7500 0.1167 0.6689 0.4878 0.3578\n',
#  'v -0.4037 0.7578 0.0625 0.6801 0.4938 0.3709\n',
#  'v -0.3984 0.7578 0.0562 0.6824 0.5043 0.3749\n',
#  'v -0.3984 0.7535 0.0625 0.6711 0.4920 0.3643\n',
#  'v -0.3984 0.7502 0.1172 0.6691 0.4880 0.3579\n',
#  'v -0.3984 0.7547 0.1250 0.6718 0.4903 0.3591\n',
#  'v -0.4046 0.7578 0.1250 0.6817 0.4921 0.3671\n',
#  'v -0.3984 0.7578 0.1304 0.6747 0.4931 0.3617\n',
#  'v -0.3984 0.7656 0.0550 0.7177 0.5378 0.4022\n',
#  'v -0.3984 0.7601 0.1328 0.6766 0.4950 0.3634\n',
#  'v -0.3984 0.7656 0.1400 0.6833 0.5031 0.3707\n',
#  'v -0.3984 0.7734 0.0589 0.7191 0.5453 0.4079\n',
#  'v -0.3984 0.7663 0.1406 0.6848 0.5050 0.3724\n',
#  'v -0.3984 0.7734 0.1481 0.6979 0.5236 0.3882\n',
#  'v -0.3984 0.7812 0.0624 0.7315 0.5652 0.4278\n',
#  'v -0.3984 0.7739 0.1484 0.6986 0.5247 0.3890\n',
#  'v -0.3995 0.7812 0.1562 0.7118 0.5441 0.4091\n',
#  'v -0.3984 0.7812 0.1559 0.7160 0.5493 0.4131\n',
#  'v -0.3984 0.7814 0.0625 0.7317 0.5655 0.4283\n',
#  'v -0.3984 0.7891 0.0681 0.7429 0.5884 0.4618\n',
#  'v -0.3984 0.7827 0.1562 0.7279 0.5622 0.4267\n',
#  'v -0.3984 0.7891 0.1578 0.7729 0.6204 0.4915\n',
#  'v -0.3984 0.7913 0.0703 0.7413 0.5907 0.4678\n',
#  'v -0.3984 0.7969 0.0778 0.7382 0.5968 0.4823\n',
#  'v -0.4023 0.7969 0.1641 0.7921 0.6578 0.5474\n',
#  'v -0.3984 0.7969 0.1596 0.7868 0.6496 0.5344\n',
#  'v -0.3984 0.7970 0.0781 0.7380 0.5967 0.4823\n',
#  'v -0.4059 0.8047 0.0859 0.7194 0.5766 0.4773\n',
#  'v -0.3984 0.7998 0.0859 0.7381 0.5999 0.4889\n',
#  'v -0.4015 0.8047 0.0938 0.7314 0.5964 0.4918\n',
#  'v -0.3984 0.8027 0.0938 0.7341 0.5980 0.4905\n',
#  'v -0.3984 0.8047 0.1001 0.7275 0.5933 0.4882\n',
#  'v -0.4002 0.8047 0.1562 0.7538 0.6186 0.5126\n',
#  'v -0.3984 0.8012 0.1562 0.7665 0.6285 0.5171\n',
#  'v -0.3984 0.8047 0.1516 0.7430 0.6071 0.5003\n',
#  'v -0.4043 0.8047 0.1641 0.7698 0.6332 0.5316\n',
#  'v -0.3984 0.8049 0.1016 0.7270 0.5931 0.4883\n',
#  'v -0.4057 0.8125 0.1094 0.7247 0.5847 0.4925\n',
#  'v -0.3984 0.8057 0.1094 0.7245 0.5921 0.4883\n',
#  'v -0.4051 0.8125 0.1172 0.7227 0.5840 0.4909\n',
#  'v -0.3984 0.8062 0.1172 0.7238 0.5918 0.4883\n',
#  'v -0.4048 0.8125 0.1250 0.7213 0.5836 0.4903\n',
#  'v -0.3984 0.8063 0.1250 0.7251 0.5928 0.4892\n',
#  'v -0.4047 0.8125 0.1328 0.7216 0.5846 0.4914\n',
#  'v -0.3984 0.8063 0.1328 0.7267 0.5940 0.4901\n',
#  'v -0.4046 0.8125 0.1406 0.7216 0.5851 0.4920\n',
#  'v -0.3984 0.8060 0.1406 0.7303 0.5967 0.4921\n',
#  'v -0.4048 0.8125 0.1484 0.7226 0.5864 0.4938\n',
#  'v -0.3984 0.8052 0.1484 0.7369 0.6016 0.4957\n',
#  'v -0.4054 0.8125 0.1562 0.7249 0.5888 0.4979\n',
#  'v -0.3912 0.7422 0.0703 0.6507 0.4717 0.3420\n',
#  'v -0.3906 0.7422 0.0675 0.6510 0.4723 0.3417\n',
#  'v -0.3906 0.7417 0.0703 0.6491 0.4705 0.3407\n',
#  'v -0.3906 0.7407 0.0781 0.6457 0.4670 0.3387\n',
#  'v -0.3922 0.7422 0.0781 0.6507 0.4709 0.3426\n',
#  'v -0.3906 0.7406 0.0859 0.6446 0.4659 0.3377\n',
#  'v -0.3922 0.7422 0.0859 0.6507 0.4707 0.3424\n',
#  'v -0.3906 0.7408 0.0938 0.6445 0.4656 0.3370\n',
#  'v -0.3921 0.7422 0.0938 0.6503 0.4704 0.3417\n',
#  'v -0.3906 0.7415 0.1016 0.6484 0.4695 0.3392\n',
#  'v -0.3914 0.7422 0.1016 0.6519 0.4725 0.3422\n',
#  'v -0.3906 0.7422 0.1047 0.6514 0.4723 0.3406\n',
#  'v -0.3921 0.7500 0.0547 0.6718 0.4969 0.3575\n',
#  'v -0.3906 0.7500 0.0523 0.6797 0.5061 0.3629\n',
#  'v -0.3906 0.7486 0.0547 0.6737 0.4980 0.3552\n',
#  'v -0.3906 0.7447 0.0625 0.6575 0.4795 0.3443\n',
#  'v -0.3959 0.7500 0.0625 0.6669 0.4881 0.3564\n',
#  'v -0.3906 0.7440 0.1094 0.6590 0.4804 0.3448\n',
#  'v -0.3906 0.7473 0.1172 0.6627 0.4825 0.3405\n',
#  'v -0.3980 0.7500 0.1172 0.6687 0.4877 0.3568\n',
#  'v -0.3906 0.7500 0.1225 0.6645 0.4858 0.3422\n',
#  'v -0.3964 0.7578 0.0547 0.6885 0.5127 0.3788\n',
#  'v -0.3906 0.7578 0.0510 0.7134 0.5418 0.3939\n',
#  'v -0.3906 0.7520 0.1250 0.6657 0.4885 0.3447\n',
#  'v -0.3906 0.7577 0.1328 0.6695 0.4961 0.3519\n',
#  'v -0.3912 0.7578 0.1328 0.6700 0.4961 0.3528\n',
#  'v -0.3906 0.7578 0.1330 0.6696 0.4963 0.3520\n',
#  'v -0.3973 0.7656 0.0547 0.7202 0.5421 0.4044\n',
#  'v -0.3906 0.7656 0.0531 0.7268 0.5593 0.4107\n',
#  'v -0.3906 0.7656 0.1406 0.6814 0.5119 0.3671\n',
#  'v -0.3913 0.7656 0.1406 0.6817 0.5113 0.3676\n',
#  'v -0.3906 0.7656 0.1407 0.6816 0.5121 0.3673\n',
#  'v -0.3906 0.7681 0.0547 0.7239 0.5584 0.4115\n',
#  'v -0.3906 0.7734 0.0589 0.7231 0.5619 0.4177\n',
#  'v -0.3906 0.7734 0.1457 0.7121 0.5475 0.4025\n',
#  'v -0.3906 0.7781 0.0625 0.7325 0.5750 0.4321\n',
#  'v -0.3982 0.7812 0.0625 0.7317 0.5657 0.4281\n',
#  'v -0.3906 0.7812 0.0651 0.7380 0.5821 0.4413\n',
#  'v -0.3906 0.7786 0.1484 0.7270 0.5685 0.4251\n',
#  'v -0.3906 0.7812 0.1501 0.7471 0.5900 0.4470\n',
#  'v -0.3955 0.7891 0.0703 0.7396 0.5877 0.4591\n',
#  'v -0.3906 0.7862 0.0703 0.7351 0.5846 0.4497\n',
#  'v -0.3906 0.7891 0.0751 0.7360 0.5892 0.4578\n',
#  'v -0.3971 0.7891 0.1562 0.7726 0.6210 0.4910\n',
#  'v -0.3906 0.7891 0.1494 0.7711 0.6217 0.4855\n',
#  'v -0.3983 0.7969 0.0781 0.7382 0.5969 0.4823\n',
#  'v -0.3906 0.7903 0.0781 0.7369 0.5918 0.4619\n',
#  'v -0.3948 0.7969 0.0859 0.7416 0.6028 0.4858\n',
#  'v -0.3906 0.7935 0.0859 0.7391 0.5970 0.4712\n',
#  'v -0.3920 0.7969 0.0938 0.7382 0.5987 0.4789\n',
#  'v -0.3906 0.7959 0.0938 0.7389 0.5984 0.4755\n',
#  'v -0.3906 0.7969 0.0987 0.7358 0.5957 0.4741\n',
#  'v -0.3912 0.7969 0.1406 0.7544 0.6117 0.4876\n',
#  'v -0.3906 0.7961 0.1406 0.7569 0.6138 0.4877\n',
#  'v -0.3906 0.7969 0.1384 0.7515 0.6090 0.4844\n',
#  'v -0.3934 0.7969 0.1484 0.7668 0.6251 0.5032\n',
#  'v -0.3906 0.7903 0.1484 0.7710 0.6226 0.4879\n',
#  'v -0.3967 0.7969 0.1562 0.7803 0.6416 0.5241\n',
#  'v -0.3983 0.8047 0.1016 0.7275 0.5935 0.4884\n',
#  'v -0.3906 0.7971 0.1016 0.7355 0.5953 0.4739\n',
#  'v -0.3976 0.8047 0.1094 0.7269 0.5932 0.4877\n',
#  'v -0.3906 0.7977 0.1094 0.7345 0.5944 0.4733\n',
#  'v -0.3973 0.8047 0.1172 0.7275 0.5936 0.4877\n',
#  'v -0.3906 0.7978 0.1172 0.7371 0.5965 0.4750\n',
#  'v -0.3972 0.8047 0.1250 0.7298 0.5953 0.4890\n',
#  'v -0.3906 0.7978 0.1250 0.7401 0.5992 0.4773\n',
#  'v -0.3972 0.8047 0.1328 0.7322 0.5972 0.4904\n',
#  'v -0.3906 0.7975 0.1328 0.7455 0.6038 0.4809\n',
#  'v -0.3975 0.8047 0.1406 0.7356 0.6000 0.4929\n',
#  'v -0.3981 0.8047 0.1484 0.7394 0.6034 0.4965\n',
#  'v -0.3834 0.7344 0.0625 0.6214 0.4523 0.3274\n',
#  'v -0.3828 0.7344 0.0601 0.6230 0.4536 0.3281\n',
#  'v -0.3828 0.7337 0.0625 0.6213 0.4523 0.3278\n',
#  'v -0.3828 0.7323 0.0703 0.6150 0.4467 0.3249\n',
#  'v -0.3846 0.7344 0.0703 0.6178 0.4491 0.3255\n',
#  'v -0.3828 0.7320 0.0781 0.6132 0.4451 0.3237\n',
#  'v -0.3848 0.7344 0.0781 0.6161 0.4475 0.3240\n',
#  'v -0.3828 0.7321 0.0859 0.6137 0.4451 0.3232\n',
#  'v -0.3848 0.7344 0.0859 0.6161 0.4471 0.3233\n',
#  'v -0.3828 0.7326 0.0938 0.6158 0.4463 0.3229\n',
#  'v -0.3844 0.7344 0.0938 0.6164 0.4467 0.3221\n',
#  'v -0.3828 0.7344 0.1016 0.6208 0.4496 0.3229\n',
#  'v -0.3828 0.7344 0.1016 0.6208 0.4496 0.3229\n',
#  'v -0.3828 0.7344 0.1016 0.6208 0.4497 0.3229\n',
#  'v -0.3855 0.7422 0.0547 0.6562 0.4824 0.3418\n',
#  'v -0.3828 0.7422 0.0488 0.6765 0.5017 0.3562\n',
#  'v -0.3828 0.7381 0.0547 0.6417 0.4689 0.3350\n',
#  'v -0.3886 0.7422 0.0625 0.6506 0.4736 0.3394\n',
#  'v -0.3828 0.7385 0.1094 0.6372 0.4606 0.3253\n',
#  'v -0.3878 0.7422 0.1094 0.6510 0.4729 0.3358\n',
#  'v -0.3828 0.7422 0.1158 0.6495 0.4691 0.3256\n',
#  'v -0.3839 0.7500 0.0469 0.7184 0.5455 0.3859\n',
#  'v -0.3828 0.7500 0.0460 0.7225 0.5490 0.3879\n',
#  'v -0.3828 0.7475 0.0469 0.7147 0.5392 0.3799\n',
#  'v -0.3828 0.7433 0.1172 0.6510 0.4707 0.3253\n',
#  'v -0.3828 0.7495 0.1250 0.6611 0.4817 0.3273\n',
#  'v -0.3846 0.7500 0.1250 0.6618 0.4842 0.3312\n',
#  'v -0.3828 0.7500 0.1257 0.6621 0.4831 0.3285\n',
#  'v -0.3828 0.7523 0.0469 0.7262 0.5546 0.3930\n',
#  'v -0.3828 0.7578 0.0492 0.7275 0.5603 0.3983\n',
#  'v -0.3828 0.7576 0.1328 0.6755 0.5033 0.3460\n',
#  'v -0.3828 0.7578 0.1330 0.6759 0.5039 0.3465\n',
#  'v -0.3828 0.7656 0.0532 0.7277 0.5675 0.4077\n',
#  'v -0.3904 0.7656 0.1406 0.6816 0.5125 0.3673\n',
#  'v -0.3828 0.7656 0.1387 0.6954 0.5293 0.3707\n',
#  'v -0.3828 0.7675 0.0547 0.7271 0.5678 0.4101\n',
#  'v -0.3828 0.7734 0.0605 0.7302 0.5712 0.4195\n',
#  'v -0.3828 0.7730 0.1406 0.7307 0.5688 0.4142\n',
#  'v -0.3828 0.7734 0.1407 0.7334 0.5720 0.4178\n',
#  'v -0.3828 0.7753 0.0625 0.7360 0.5781 0.4280\n',
#  'v -0.3828 0.7812 0.0703 0.7378 0.5867 0.4443\n',
#  'v -0.3892 0.7812 0.1484 0.7524 0.5978 0.4540\n',
#  'v -0.3828 0.7812 0.1417 0.7650 0.6111 0.4639\n',
#  'v -0.3828 0.7813 0.0703 0.7377 0.5867 0.4443\n',
#  'v -0.3896 0.7891 0.0781 0.7367 0.5907 0.4584\n',
#  'v -0.3828 0.7835 0.0781 0.7357 0.5867 0.4472\n',
#  'v -0.3869 0.7891 0.0859 0.7380 0.5938 0.4592\n',
#  'v -0.3828 0.7858 0.0859 0.7372 0.5895 0.4525\n',
#  'v -0.3850 0.7891 0.0938 0.7392 0.5946 0.4594\n',
#  'v -0.3828 0.7874 0.0938 0.7393 0.5919 0.4564\n',
#  'v -0.3835 0.7891 0.1016 0.7414 0.5947 0.4603\n',
#  'v -0.3828 0.7885 0.1016 0.7410 0.5936 0.4591\n',
#  'v -0.3829 0.7891 0.1094 0.7441 0.5963 0.4616\n',
#  'v -0.3828 0.7889 0.1094 0.7440 0.5961 0.4613\n',
#  'v -0.3831 0.7891 0.1172 0.7486 0.6001 0.4643\n',
#  'v -0.3828 0.7888 0.1172 0.7484 0.5996 0.4637\n',
#  'v -0.3837 0.7891 0.1250 0.7543 0.6053 0.4679\n',
#  'v -0.3828 0.7881 0.1250 0.7541 0.6038 0.4658\n',
#  'v -0.3852 0.7891 0.1328 0.7610 0.6125 0.4727\n',
#  'v -0.3828 0.7861 0.1328 0.7597 0.6075 0.4658\n',
#  'v -0.3871 0.7891 0.1406 0.7651 0.6164 0.4768\n',
#  'v -0.3828 0.7820 0.1406 0.7633 0.6097 0.4635\n',
#  'v -0.3902 0.7891 0.1484 0.7704 0.6210 0.4844\n',
#  'v -0.3904 0.7969 0.1016 0.7360 0.5956 0.4736\n',
#  'v -0.3899 0.7969 0.1094 0.7366 0.5956 0.4723\n',
#  'v -0.3898 0.7969 0.1172 0.7395 0.5981 0.4741\n',
#  'v -0.3898 0.7969 0.1250 0.7428 0.6010 0.4765\n',
#  'v -0.3900 0.7969 0.1328 0.7471 0.6048 0.4801\n',
#  'v -0.3768 0.7266 0.0547 0.6227 0.4549 0.3325\n',
#  'v -0.3750 0.7266 0.0471 0.6331 0.4660 0.3400\n',
#  'v -0.3750 0.7232 0.0547 0.6159 0.4522 0.3316\n',
#  'v -0.3750 0.7210 0.0625 0.6081 0.4465 0.3285\n',
#  'v -0.3777 0.7266 0.0625 0.6180 0.4501 0.3294\n',
#  'v -0.3750 0.7202 0.0703 0.6053 0.4437 0.3265\n',
#  'v -0.3781 0.7266 0.0703 0.6160 0.4478 0.3277\n',
#  'v -0.3750 0.7203 0.0781 0.6042 0.4422 0.3250\n',
#  'v -0.3783 0.7266 0.0781 0.6144 0.4465 0.3268\n',
#  'v -0.3750 0.7212 0.0859 0.6107 0.4465 0.3275\n',
#  'v -0.3782 0.7266 0.0859 0.6161 0.4472 0.3270\n',
#  'v -0.3750 0.7231 0.0938 0.6215 0.4540 0.3319\n',
#  'v -0.3772 0.7266 0.0938 0.6241 0.4537 0.3311\n',
#  'v -0.3750 0.7266 0.1015 0.6377 0.4665 0.3394\n',
#  'v -0.3773 0.7344 0.0469 0.6633 0.4894 0.3530\n',
#  'v -0.3750 0.7344 0.0421 0.6869 0.5125 0.3707\n',
#  'v -0.3750 0.7268 0.0469 0.6356 0.4682 0.3417\n',
#  'v -0.3805 0.7344 0.0547 0.6336 0.4625 0.3336\n',
#  'v -0.3750 0.7266 0.1016 0.6378 0.4666 0.3395\n',
#  'v -0.3750 0.7325 0.1094 0.6506 0.4738 0.3376\n',
#  'v -0.3771 0.7344 0.1094 0.6446 0.4674 0.3314\n',
#  'v -0.3750 0.7344 0.1116 0.6536 0.4737 0.3336\n',
#  'v -0.3806 0.7422 0.0469 0.6895 0.5134 0.3641\n',
#  'v -0.3750 0.7422 0.0423 0.7260 0.5481 0.3887\n',
#  'v -0.3750 0.7399 0.1172 0.6576 0.4733 0.3242\n',
#  'v -0.3802 0.7422 0.1172 0.6515 0.4699 0.3236\n',
#  'v -0.3750 0.7422 0.1197 0.6567 0.4722 0.3201\n',
#  'v -0.3750 0.7500 0.0441 0.7416 0.5637 0.3922\n',
#  'v -0.3750 0.7489 0.1250 0.6603 0.4732 0.3120\n',
#  'v -0.3750 0.7500 0.1259 0.6637 0.4783 0.3163\n',
#  'v -0.3750 0.7545 0.0469 0.7349 0.5624 0.3907\n',
#  'v -0.3750 0.7578 0.0493 0.7340 0.5653 0.3931\n',
#  'v -0.3818 0.7578 0.1328 0.6785 0.5057 0.3468\n',
#  'v -0.3750 0.7578 0.1310 0.6962 0.5182 0.3486\n',
#  'v -0.3750 0.7640 0.0547 0.7349 0.5733 0.4005\n',
#  'v -0.3788 0.7656 0.0547 0.7316 0.5699 0.4047\n',
#  'v -0.3750 0.7656 0.0565 0.7338 0.5704 0.4001\n',
#  'v -0.3750 0.7621 0.1328 0.7119 0.5398 0.3670\n',
#  'v -0.3750 0.7656 0.1341 0.7282 0.5584 0.3859\n',
#  'v -0.3807 0.7734 0.0625 0.7356 0.5734 0.4192\n',
#  'v -0.3750 0.7697 0.0625 0.7341 0.5681 0.4038\n',
#  'v -0.3750 0.7734 0.0694 0.7345 0.5697 0.4114\n',
#  'v -0.3757 0.7734 0.1328 0.7562 0.5893 0.4274\n',
#  'v -0.3750 0.7706 0.1328 0.7519 0.5831 0.4165\n',
#  'v -0.3750 0.7734 0.1318 0.7560 0.5885 0.4262\n',
#  'v -0.3827 0.7734 0.1406 0.7339 0.5724 0.4180\n',
#  'v -0.3828 0.7812 0.0703 0.7377 0.5867 0.4443\n',
#  'v -0.3750 0.7736 0.0703 0.7345 0.5699 0.4119\n',
#  'v -0.3814 0.7812 0.0781 0.7358 0.5837 0.4411\n',
#  'v -0.3750 0.7752 0.0781 0.7333 0.5703 0.4151\n',
#  'v -0.3798 0.7812 0.0859 0.7368 0.5826 0.4391\n',
#  'v -0.3750 0.7767 0.0859 0.7342 0.5718 0.4191\n',
#  'v -0.3786 0.7812 0.0938 0.7398 0.5836 0.4391\n',
#  'v -0.3750 0.7779 0.0938 0.7370 0.5746 0.4234\n',
#  'v -0.3781 0.7812 0.1016 0.7431 0.5857 0.4401\n',
#  'v -0.3750 0.7780 0.1016 0.7393 0.5764 0.4250\n',
#  'v -0.3781 0.7812 0.1094 0.7467 0.5888 0.4425\n',
#  'v -0.3750 0.7779 0.1094 0.7425 0.5790 0.4270\n',
#  'v -0.3783 0.7812 0.1172 0.7514 0.5931 0.4460\n',
#  'v -0.3750 0.7773 0.1172 0.7464 0.5821 0.4282\n',
#  'v -0.3790 0.7812 0.1250 0.7564 0.5983 0.4505\n',
#  'v -0.3750 0.7759 0.1250 0.7520 0.5861 0.4288\n',
#  'v -0.3801 0.7812 0.1328 0.7606 0.6039 0.4560\n',
#  'v -0.3824 0.7812 0.1406 0.7640 0.6097 0.4624\n',
#  'v -0.3674 0.7031 0.0625 0.6296 0.4636 0.3414\n',
#  'v -0.3672 0.7031 0.0579 0.6304 0.4647 0.3421\n',
#  'v -0.3672 0.7028 0.0625 0.6305 0.4643 0.3417\n',
#  'v -0.3672 0.7026 0.0703 0.6291 0.4625 0.3396\n',
#  'v -0.3676 0.7031 0.0703 0.6278 0.4613 0.3391\n',
#  'v -0.3672 0.7031 0.0735 0.6284 0.4618 0.3386\n',
#  'v -0.3684 0.7109 0.0469 0.6184 0.4583 0.3357\n',
#  'v -0.3672 0.7109 0.0429 0.6172 0.4578 0.3339\n',
#  'v -0.3672 0.7075 0.0469 0.6255 0.4629 0.3394\n',
#  'v -0.3672 0.7035 0.0547 0.6303 0.4649 0.3423\n',
#  'v -0.3696 0.7109 0.0547 0.6168 0.4561 0.3345\n',
#  'v -0.3700 0.7109 0.0625 0.6150 0.4537 0.3325\n',
#  'v -0.3701 0.7109 0.0703 0.6144 0.4527 0.3316\n',
#  'v -0.3672 0.7041 0.0781 0.6276 0.4611 0.3374\n',
#  'v -0.3701 0.7109 0.0781 0.6157 0.4535 0.3316\n',
#  'v -0.3672 0.7067 0.0859 0.6259 0.4602 0.3352\n',
#  'v -0.3692 0.7109 0.0859 0.6181 0.4551 0.3314\n',
#  'v -0.3672 0.7109 0.0934 0.6211 0.4576 0.3313\n',
#  'v -0.3672 0.7188 0.0391 0.6344 0.4750 0.3446\n',
#  'v -0.3672 0.7188 0.0390 0.6350 0.4755 0.3450\n',
#  'v -0.3672 0.7186 0.0391 0.6329 0.4738 0.3437\n',
#  'v -0.3700 0.7188 0.0469 0.6155 0.4583 0.3325\n',
#  'v -0.3717 0.7188 0.0547 0.6112 0.4544 0.3326\n',
#  'v -0.3733 0.7188 0.0625 0.6049 0.4477 0.3294\n',
#  'v -0.3738 0.7188 0.0703 0.6029 0.4445 0.3270\n',
#  'v -0.3738 0.7188 0.0781 0.6040 0.4451 0.3273\n',
#  'v -0.3726 0.7188 0.0859 0.6124 0.4535 0.3329\n',
#  'v -0.3672 0.7113 0.0938 0.6208 0.4575 0.3311\n',
#  'v -0.3705 0.7188 0.0938 0.6201 0.4594 0.3329\n',
#  'v -0.3672 0.7188 0.1012 0.6219 0.4593 0.3282\n',
#  'v -0.3689 0.7266 0.0391 0.6894 0.5212 0.3798\n',
#  'v -0.3672 0.7266 0.0369 0.6977 0.5297 0.3862\n',
#  'v -0.3749 0.7266 0.0469 0.6346 0.4675 0.3411\n',
#  'v -0.3672 0.7191 0.1016 0.6230 0.4600 0.3285\n',
#  'v -0.3750 0.7266 0.1016 0.6378 0.4667 0.3396\n',
#  'v -0.3672 0.7266 0.1089 0.6467 0.4750 0.3352\n',
#  'v -0.3699 0.7344 0.0391 0.7297 0.5558 0.4034\n',
#  'v -0.3672 0.7344 0.0375 0.7366 0.5640 0.4093\n',
#  'v -0.3672 0.7271 0.1094 0.6482 0.4758 0.3354\n',
#  'v -0.3672 0.7344 0.1150 0.6662 0.4836 0.3342\n',
#  'v -0.3672 0.7390 0.0391 0.7479 0.5732 0.4110\n',
#  'v -0.3672 0.7422 0.0404 0.7518 0.5756 0.4087\n',
#  'v -0.3672 0.7377 0.1172 0.6662 0.4822 0.3291\n',
#  'v -0.3672 0.7422 0.1202 0.6653 0.4800 0.3221\n',
#  'v -0.3672 0.7500 0.0441 0.7444 0.5672 0.3929\n',
#  'v -0.3692 0.7500 0.1250 0.6704 0.4809 0.3137\n',
#  'v -0.3672 0.7500 0.1247 0.6777 0.4910 0.3239\n',
#  'v -0.3672 0.7530 0.0469 0.7367 0.5625 0.3886\n',
#  'v -0.3672 0.7578 0.0527 0.7319 0.5602 0.3857\n',
#  'v -0.3672 0.7512 0.1250 0.6827 0.4978 0.3298\n',
#  'v -0.3672 0.7578 0.1267 0.7178 0.5375 0.3623\n',
#  'v -0.3672 0.7592 0.0547 0.7302 0.5594 0.3849\n',
#  'v -0.3701 0.7656 0.0625 0.7354 0.5708 0.3945\n',
#  'v -0.3672 0.7635 0.0625 0.7370 0.5695 0.3937\n',
#  'v -0.3672 0.7656 0.0668 0.7402 0.5708 0.3981\n',
#  'v -0.3738 0.7656 0.1328 0.7342 0.5642 0.3895\n',
#  'v -0.3672 0.7656 0.1251 0.7517 0.5797 0.4042\n',
#  'v -0.3748 0.7734 0.0703 0.7345 0.5697 0.4112\n',
#  'v -0.3672 0.7663 0.0703 0.7411 0.5707 0.3993\n',
#  'v -0.3736 0.7734 0.0781 0.7344 0.5691 0.4097\n',
#  'v -0.3672 0.7676 0.0781 0.7395 0.5684 0.3998\n',
#  'v -0.3724 0.7734 0.0859 0.7350 0.5687 0.4083\n',
#  'v -0.3672 0.7686 0.0859 0.7374 0.5659 0.3995\n',
#  'v -0.3717 0.7734 0.0938 0.7374 0.5700 0.4086\n',
#  'v -0.3672 0.7691 0.0938 0.7366 0.5654 0.3999\n',
#  'v -0.3717 0.7734 0.1016 0.7397 0.5716 0.4098\n',
#  'v -0.3672 0.7690 0.1016 0.7397 0.5677 0.4015\n',
#  'v -0.3718 0.7734 0.1094 0.7428 0.5741 0.4118\n',
#  'v -0.3672 0.7686 0.1094 0.7438 0.5715 0.4039\n',
#  'v -0.3723 0.7734 0.1172 0.7466 0.5777 0.4151\n',
#  'v -0.3672 0.7677 0.1172 0.7468 0.5746 0.4045\n',
#  'v -0.3733 0.7734 0.1250 0.7518 0.5833 0.4204\n',
#  'v -0.3672 0.7657 0.1250 0.7517 0.5797 0.4042\n',
#  'v -0.3608 0.6875 0.0469 0.6691 0.5053 0.3803\n',
#  'v -0.3594 0.6875 0.0399 0.6774 0.5116 0.3823\n',
#  'v -0.3594 0.6850 0.0469 0.6801 0.5137 0.3865\n',
#  'v -0.3594 0.6843 0.0547 0.6785 0.5125 0.3859\n',
#  'v -0.3612 0.6875 0.0547 0.6673 0.5035 0.3793\n',
#  'v -0.3594 0.6841 0.0625 0.6779 0.5121 0.3858\n',
#  'v -0.3614 0.6875 0.0625 0.6665 0.5020 0.3781\n',
#  'v -0.3594 0.6846 0.0703 0.6796 0.5134 0.3867\n',
#  'v -0.3613 0.6875 0.0703 0.6681 0.5029 0.3786\n',
#  'v -0.3594 0.6866 0.0781 0.6815 0.5133 0.3840\n',
#  'v -0.3600 0.6875 0.0781 0.6774 0.5097 0.3814\n',
#  'v -0.3594 0.6875 0.0803 0.6812 0.5125 0.3820\n',
#  'v -0.3611 0.6953 0.0391 0.6540 0.4934 0.3636\n',
#  'v -0.3594 0.6953 0.0335 0.6614 0.5010 0.3667\n',
#  'v -0.3594 0.6883 0.0391 0.6763 0.5106 0.3806\n',
#  'v -0.3622 0.6953 0.0469 0.6506 0.4884 0.3608\n',
#  'v -0.3627 0.6953 0.0547 0.6498 0.4863 0.3593\n',
#  'v -0.3628 0.6953 0.0625 0.6494 0.4850 0.3580\n',
#  'v -0.3628 0.6953 0.0703 0.6504 0.4855 0.3585\n',
#  'v -0.3621 0.6953 0.0781 0.6548 0.4885 0.3590\n',
#  'v -0.3594 0.6926 0.0859 0.6748 0.5066 0.3715\n',
#  'v -0.3604 0.6953 0.0859 0.6658 0.4985 0.3638\n',
#  'v -0.3594 0.6953 0.0885 0.6678 0.5012 0.3641\n',
#  'v -0.3595 0.7031 0.0312 0.6558 0.4959 0.3578\n',
#  'v -0.3594 0.7031 0.0309 0.6581 0.4982 0.3595\n',
#  'v -0.3594 0.7022 0.0312 0.6565 0.4972 0.3587\n',
#  'v -0.3625 0.7031 0.0391 0.6374 0.4753 0.3443\n',
#  'v -0.3649 0.7031 0.0469 0.6347 0.4703 0.3437\n',
#  'v -0.3669 0.7031 0.0547 0.6312 0.4657 0.3427\n',
#  'v -0.3664 0.7031 0.0781 0.6306 0.4639 0.3387\n',
#  'v -0.3640 0.7031 0.0859 0.6359 0.4698 0.3396\n',
#  'v -0.3594 0.7031 0.0936 0.6398 0.4747 0.3350\n',
#  'v -0.3599 0.7109 0.0312 0.6797 0.5197 0.3799\n',
#  'v -0.3594 0.7109 0.0303 0.6852 0.5254 0.3843\n',
#  'v -0.3646 0.7109 0.0391 0.6226 0.4635 0.3362\n',
#  'v -0.3594 0.7034 0.0938 0.6394 0.4742 0.3346\n',
#  'v -0.3668 0.7109 0.0938 0.6217 0.4582 0.3314\n',
#  'v -0.3594 0.7109 0.0992 0.6300 0.4656 0.3273\n',
#  'v -0.3597 0.7188 0.0312 0.7043 0.5428 0.3984\n',
#  'v -0.3594 0.7188 0.0309 0.7059 0.5444 0.3996\n',
#  'v -0.3594 0.7144 0.1016 0.6255 0.4612 0.3240\n',
#  'v -0.3665 0.7188 0.1016 0.6220 0.4591 0.3273\n',
#  'v -0.3594 0.7188 0.1048 0.6269 0.4608 0.3226\n',
#  'v -0.3594 0.7199 0.0312 0.7109 0.5488 0.4027\n',
#  'v -0.3594 0.7266 0.0332 0.7413 0.5769 0.4235\n',
#  'v -0.3594 0.7255 0.1094 0.6380 0.4663 0.3226\n',
#  'v -0.3645 0.7266 0.1094 0.6432 0.4718 0.3305\n',
#  'v -0.3594 0.7266 0.1102 0.6394 0.4668 0.3222\n',
#  'v -0.3594 0.7344 0.0363 0.7535 0.5876 0.4288\n',
#  'v -0.3594 0.7344 0.1150 0.6543 0.4767 0.3253\n',
#  'v -0.3594 0.7390 0.0391 0.7465 0.5772 0.4141\n',
#  'v -0.3594 0.7422 0.0412 0.7422 0.5722 0.4073\n',
#  'v -0.3594 0.7384 0.1172 0.6675 0.4897 0.3339\n',
#  'v -0.3594 0.7422 0.1192 0.6795 0.5018 0.3421\n',
#  'v -0.3594 0.7488 0.0469 0.7379 0.5687 0.4009\n',
#  'v -0.3615 0.7500 0.0469 0.7347 0.5637 0.3952\n',
#  'v -0.3594 0.7500 0.0483 0.7309 0.5616 0.3951\n',
#  'v -0.3594 0.7500 0.1211 0.7066 0.5297 0.3634\n',
#  'v -0.3659 0.7578 0.0547 0.7276 0.5549 0.3823\n',
#  'v -0.3594 0.7528 0.0547 0.7213 0.5482 0.3829\n',
#  'v -0.3616 0.7578 0.0625 0.7287 0.5525 0.3842\n',
#  'v -0.3594 0.7562 0.0625 0.7271 0.5506 0.3845\n',
#  'v -0.3594 0.7578 0.0669 0.7310 0.5542 0.3881\n',
#  'v -0.3608 0.7578 0.1172 0.7350 0.5573 0.3882\n',
#  'v -0.3594 0.7554 0.1172 0.7315 0.5534 0.3856\n',
#  'v -0.3594 0.7578 0.1147 0.7342 0.5567 0.3897\n',
#  'v -0.3659 0.7578 0.1250 0.7225 0.5427 0.3685\n',
#  'v -0.3666 0.7656 0.0703 0.7410 0.5705 0.3985\n',
#  'v -0.3594 0.7583 0.0703 0.7317 0.5549 0.3889\n',
#  'v -0.3656 0.7656 0.0781 0.7422 0.5700 0.3993\n',
#  'v -0.3594 0.7593 0.0781 0.7336 0.5567 0.3906\n',
#  'v -0.3649 0.7656 0.0859 0.7421 0.5690 0.3993\n',
#  'v -0.3594 0.7599 0.0859 0.7343 0.5574 0.3913\n',
#  'v -0.3646 0.7656 0.0938 0.7422 0.5689 0.3994\n',
#  'v -0.3594 0.7601 0.0938 0.7349 0.5580 0.3920\n',
#  'v -0.3646 0.7656 0.1016 0.7428 0.5697 0.4001\n',
#  'v -0.3594 0.7598 0.1016 0.7339 0.5572 0.3914\n',
#  'v -0.3648 0.7656 0.1094 0.7437 0.5710 0.4010\n',
#  'v -0.3594 0.7590 0.1094 0.7326 0.5560 0.3900\n',
#  'v -0.3655 0.7656 0.1172 0.7460 0.5737 0.4021\n',
#  'v -0.3672 0.7656 0.1250 0.7517 0.5797 0.4042\n',
#  'v -0.3533 0.6719 0.0391 0.6959 0.5292 0.3926\n',
#  'v -0.3516 0.6719 0.0313 0.7006 0.5317 0.3939\n',
#  'v -0.3516 0.6690 0.0391 0.6980 0.5302 0.3936\n',
#  'v -0.3516 0.6682 0.0469 0.6935 0.5274 0.3923\n',
#  'v -0.3537 0.6719 0.0469 0.6912 0.5269 0.3913\n',
#  'v -0.3516 0.6681 0.0547 0.6910 0.5264 0.3918\n',
#  'v -0.3539 0.6719 0.0547 0.6891 0.5260 0.3904\n',
#  'v -0.3516 0.6685 0.0625 0.6920 0.5274 0.3918\n',
#  'v -0.3538 0.6719 0.0625 0.6891 0.5260 0.3899\n',
#  'v -0.3516 0.6702 0.0703 0.6977 0.5313 0.3934\n',
#  'v -0.3527 0.6719 0.0703 0.6951 0.5296 0.3920\n',
#  'v -0.3516 0.6719 0.0751 0.7005 0.5330 0.3942\n',
#  'v -0.3533 0.6797 0.0312 0.7031 0.5337 0.3938\n',
#  'v -0.3516 0.6797 0.0265 0.7057 0.5360 0.3953\n',
#  'v -0.3516 0.6719 0.0312 0.7006 0.5317 0.3939\n',
#  'v -0.3547 0.6797 0.0391 0.6998 0.5301 0.3919\n',
#  'v -0.3557 0.6797 0.0469 0.6931 0.5242 0.3895\n',
#  'v -0.3561 0.6797 0.0547 0.6899 0.5221 0.3888\n',
#  'v -0.3560 0.6797 0.0625 0.6897 0.5225 0.3893\n',
#  'v -0.3554 0.6797 0.0703 0.6947 0.5268 0.3907\n',
#  'v -0.3516 0.6744 0.0781 0.7027 0.5338 0.3939\n',
#  'v -0.3537 0.6797 0.0781 0.6996 0.5314 0.3912\n',
#  'v -0.3516 0.6797 0.0836 0.7051 0.5328 0.3899\n',
#  'v -0.3551 0.6875 0.0312 0.6940 0.5287 0.3885\n',
#  'v -0.3516 0.6875 0.0244 0.6955 0.5287 0.3859\n',
#  'v -0.3590 0.6875 0.0391 0.6800 0.5137 0.3832\n',
#  'v -0.3516 0.6828 0.0859 0.7063 0.5324 0.3880\n',
#  'v -0.3547 0.6875 0.0859 0.6987 0.5289 0.3850\n',
#  'v -0.3516 0.6875 0.0893 0.7026 0.5300 0.3831\n',
#  'v -0.3517 0.6953 0.0234 0.7063 0.5469 0.3970\n',
#  'v -0.3516 0.6953 0.0232 0.7074 0.5482 0.3983\n',
#  'v -0.3516 0.6939 0.0234 0.7038 0.5435 0.3951\n',
#  'v -0.3576 0.6953 0.0312 0.6714 0.5110 0.3719\n',
#  'v -0.3516 0.6951 0.0938 0.6828 0.5149 0.3630\n',
#  'v -0.3518 0.6953 0.0938 0.6814 0.5138 0.3618\n',
#  'v -0.3516 0.6953 0.0939 0.6817 0.5140 0.3619\n',
#  'v -0.3516 0.6985 0.0234 0.7125 0.5552 0.4026\n',
#  'v -0.3516 0.7031 0.0238 0.7177 0.5609 0.4080\n',
#  'v -0.3591 0.7031 0.0938 0.6401 0.4751 0.3347\n',
#  'v -0.3516 0.7031 0.0982 0.6585 0.4947 0.3418\n',
#  'v -0.3516 0.7109 0.0255 0.7273 0.5718 0.4209\n',
#  'v -0.3516 0.7109 0.1015 0.6453 0.4811 0.3338\n',
#  'v -0.3516 0.7188 0.0280 0.7315 0.5756 0.4269\n',
#  'v -0.3516 0.7111 0.1016 0.6450 0.4808 0.3336\n',
#  'v -0.3516 0.7188 0.1053 0.6343 0.4682 0.3245\n',
#  'v -0.3516 0.7259 0.0312 0.7449 0.5877 0.4348\n',
#  'v -0.3516 0.7266 0.0316 0.7456 0.5882 0.4351\n',
#  'v -0.3516 0.7264 0.1094 0.6387 0.4688 0.3214\n',
#  'v -0.3516 0.7266 0.1095 0.6388 0.4688 0.3213\n',
#  'v -0.3516 0.7344 0.0364 0.7502 0.5902 0.4334\n',
#  'v -0.3516 0.7344 0.1135 0.6528 0.4809 0.3289\n',
#  'v -0.3516 0.7372 0.0391 0.7381 0.5748 0.4168\n',
#  'v -0.3516 0.7422 0.0438 0.7178 0.5540 0.3976\n',
#  'v -0.3557 0.7422 0.1172 0.6861 0.5123 0.3518\n',
#  'v -0.3516 0.7422 0.1149 0.6863 0.5176 0.3620\n',
#  'v -0.3516 0.7441 0.0469 0.7155 0.5518 0.3957\n',
#  'v -0.3549 0.7500 0.0547 0.7249 0.5567 0.3934\n',
#  'v -0.3516 0.7478 0.0547 0.7130 0.5464 0.3894\n',
#  'v -0.3516 0.7500 0.0598 0.7111 0.5409 0.3856\n',
#  'v -0.3557 0.7500 0.1172 0.7232 0.5511 0.3849\n',
#  'v -0.3516 0.7500 0.1117 0.7191 0.5480 0.3902\n',
#  'v -0.3516 0.7505 0.0625 0.7119 0.5411 0.3860\n',
#  ...]

# %%
with open('/Users/test/Desktop/hmr/models/neutral_smpl_with_cocoplus_reg.pkl', 'rb') as f:
    dd = pickle.load(f, encoding="latin-1")

# %%
dd['weights'].shape
# Out:
# (6890, 24)

# %%
weights_for_pifu = dd['weights'][argmins]

# %%
weights_for_pifu.shape
# Out:
# (42500, 24)

# %%
np.save('weights_for_pifu.npy', dd['weights'])

# %%
np.save('verts_pifu.npy', verts_smpl)

# %%
basketbolist_smpl = np.load('basketbolist_smpl.npy')[0]

# %%
# basketbolist_smpl[:,1] = -basketbolist_smpl[:,1]
# basketbolist_smpl[:,2] = -basketbolist_smpl[:,2]

# %%
new_content = change_verts_in_mesh('../smpl_tf.obj', basketbolist_smpl)
# Out:
# 100%|██████████| 20666/20666 [00:00<00:00, 421461.64it/s]

# %%
with open('../basketbolist_smpl.obj', 'w') as file:
    file.write(new_content)

# %%
verts_pifu_reversed = verts_pifu.copy()
verts_pifu_reversed[:,1] = -verts_pifu_reversed[:,1]
verts_pifu_reversed[:,2] = -verts_pifu_reversed[:,2]

new_content = change_verts_in_mesh('../../Downloads/result_levon.obj', verts_pifu_reversed, textures=True)
with open('../delete_me.obj', 'w') as file:
    file.write(new_content)
# Out:
# 100%|██████████| 127500/127500 [00:00<00:00, 576897.05it/s]

# %%
verts_pifu_reversed_aligned = mesh_verts_align(basketbolist_smpl, verts_pifu_reversed)

# %%
new_content = change_verts_in_mesh('../../Downloads/result_levon.obj', verts_pifu_reversed_aligned, textures=True)
with open('../delete_me.obj', 'w') as file:
    file.write(new_content)
# Out:
# 100%|██████████| 127500/127500 [00:00<00:00, 517716.05it/s]

# %%
np.save('verts_pifu_reversed_aligned.npy', verts_pifu_reversed_aligned)

# %%
start = time()
dists = pairwise_dist(verts_pifu_reversed_aligned, basketbolist_smpl)
print(time()-start)
argmins = np.argmin(dists, axis=-1)

blend_weights_for_pifu = dd['weights'][argmins]
# Out:
# 3.0656089782714844

# %%
np.save('weights_for_pifu.npy', blend_weights_for_pifu)

# %%
pifu_zero = np.load('/Users/test/Desktop/hmr/pifu_another_pose.npy')[0]
new_content = change_verts_in_mesh('../../Downloads/result_levon.obj', pifu_zero, textures=True)
with open('../pifu_another_pose.obj', 'w') as file:
    file.write(new_content)
# Out:
# 100%|██████████| 127500/127500 [00:00<00:00, 568310.92it/s]
